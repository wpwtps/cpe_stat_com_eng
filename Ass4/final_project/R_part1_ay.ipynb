# %%
getwd()
# Out:
# [1] "C:/Users/User/Documents/stat2020/final_project"

# %%
df <- read.csv("nor_ayu.csv", sep=",", header=T,fileEncoding="UTF-8-BOM")
attach(df)
df
# Out:
#    X  X0         X1         X2         X3          X4         X5
# 1   0 0.00000000 0.00000000 0.00000000 0.100631769 0.00000000 0.00000000
# 2   1 0.04347826 0.08519104 0.01840443 0.119584838 0.04791777 0.03399137
# 3   2 0.08695652 0.10898274 0.07697107 0.101985560 0.07480627 0.08720094
# 4   3 0.13043478 0.11326167 0.13538174 0.066335740 0.06563043 0.17753955
# 5   4 0.17391304 0.14175457 0.07494346 0.024368231 0.09917467 0.12341483
# 6   5 0.21739130 0.23201175 0.06121812 0.003158845 0.16644316 0.14890835
# 7   6 0.26086957 0.23176132 0.11760119 0.010379061 0.17258139 0.16158975
# 8   7 0.30434783 0.26893625 0.12750526 0.000000000 0.21326739 0.18433782
# 9   8 0.34782609 0.34789930 0.14216642 0.000000000 0.30631733 0.23924696
# 10  9 0.39130435 0.39419734 0.21274273 0.130415162 0.34152214 0.29899333
# 11 10 0.43478261 0.40028368 0.22100912 0.152527076 0.35592717 0.31376651
# 12 11 0.47826087 0.47799461 0.27653435 0.309115523 0.43623714 0.38985488
# ...

# %%
ayt = df[0:21]

# %%
ayt
# Out:
#    X  X0         X1         X2         X3          X4         X5
# 1   0 0.00000000 0.00000000 0.00000000 0.100631769 0.00000000 0.00000000
# 2   1 0.04347826 0.08519104 0.01840443 0.119584838 0.04791777 0.03399137
# 3   2 0.08695652 0.10898274 0.07697107 0.101985560 0.07480627 0.08720094
# 4   3 0.13043478 0.11326167 0.13538174 0.066335740 0.06563043 0.17753955
# 5   4 0.17391304 0.14175457 0.07494346 0.024368231 0.09917467 0.12341483
# 6   5 0.21739130 0.23201175 0.06121812 0.003158845 0.16644316 0.14890835
# 7   6 0.26086957 0.23176132 0.11760119 0.010379061 0.17258139 0.16158975
# 8   7 0.30434783 0.26893625 0.12750526 0.000000000 0.21326739 0.18433782
# 9   8 0.34782609 0.34789930 0.14216642 0.000000000 0.30631733 0.23924696
# 10  9 0.39130435 0.39419734 0.21274273 0.130415162 0.34152214 0.29899333
# 11 10 0.43478261 0.40028368 0.22100912 0.152527076 0.35592717 0.31376651
# 12 11 0.47826087 0.47799461 0.27653435 0.309115523 0.43623714 0.38985488
# ...

# %%
ay = df
ay
# Out:
#    X  X0         X1         X2         X3          X4         X5
# 1   0 0.00000000 0.00000000 0.00000000 0.100631769 0.00000000 0.00000000
# 2   1 0.04347826 0.08519104 0.01840443 0.119584838 0.04791777 0.03399137
# 3   2 0.08695652 0.10898274 0.07697107 0.101985560 0.07480627 0.08720094
# 4   3 0.13043478 0.11326167 0.13538174 0.066335740 0.06563043 0.17753955
# 5   4 0.17391304 0.14175457 0.07494346 0.024368231 0.09917467 0.12341483
# 6   5 0.21739130 0.23201175 0.06121812 0.003158845 0.16644316 0.14890835
# 7   6 0.26086957 0.23176132 0.11760119 0.010379061 0.17258139 0.16158975
# 8   7 0.30434783 0.26893625 0.12750526 0.000000000 0.21326739 0.18433782
# 9   8 0.34782609 0.34789930 0.14216642 0.000000000 0.30631733 0.23924696
# 10  9 0.39130435 0.39419734 0.21274273 0.130415162 0.34152214 0.29899333
# 11 10 0.43478261 0.40028368 0.22100912 0.152527076 0.35592717 0.31376651
# 12 11 0.47826087 0.47799461 0.27653435 0.309115523 0.43623714 0.38985488
# ...

# %%
x1 <- X1
x2 <- X2
x3 <- X3
x4 <- X4
x5 <- X5
x6 <- X6
x7 <- X7
x8 <- X8
x9<- X9
x10<-X10
x11<- X11
x12<- X12
x13<- X13
x14<- X14
x15<- X15
x16<- X16
x17<- X17
x18<- X18
x19<- X19
X20<- X20
X21<- X21
x22<- X22
x23<- X23
x24<- X24
x25<- X25
x26<- X26
x27<- X27
x28<- X28
x29<- X29
x30<-X30
x31<- X31
x32<- X32

y <- X0

# %%
model <- lm(y ~ X1+X2+X3+X4+X5+X6+X7+X8+X9+X10+X11+X12+X13+X14+X15+X16+X17+X18+X19+X20+X21)
summary(model)
# Out:
# Call:
# lm(formula = y ~ X1 + X2 + X3 + X4 + X5 + X6 + X7 + X8 + X9 +
#     X10 + X11 + X12 + X13 + X14 + X15 + X16 + X17 + X18 + X19 +
#     X20 + X21)
#
# Residuals:
#          1          2          3          4          5          6          7
#  0.0003360 -0.0011076 -0.0027609  0.0054413 -0.0029006  0.0019336 -0.0039028
#          8          9         10         11         12         13         14
#  0.0008129  0.0031275 -0.0045182  0.0035174  0.0003185  0.0007780 -0.0013535
#         15         16         17         18         19         20         21
#  0.0015197  0.0008386 -0.0024601  0.0016674 -0.0009850 -0.0012961  0.0015755
#         22         23         24
#  0.0014380 -0.0026285  0.0006087
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.01019    0.01250  -0.815   0.5006
# X1           1.22080    0.98128   1.244   0.3395
# X2          -0.25079    0.08642  -2.902   0.1011
# X3          -0.27374    0.07021  -3.899   0.0599 .
# ...

# %%
model <- lm(y ~ X22+X23+X24+X25+X26+X27+X28+X29+X30+X31+X32)
summary(model)
# Out:
# Call:
# lm(formula = y ~ X22 + X23 + X24 + X25 + X26 + X27 + X28 + X29 +
#     X30 + X31 + X32)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.028819 -0.019337  0.000767  0.010855  0.041149
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.013938   0.103353   0.135   0.8950
# X22          0.133417   0.113203   1.179   0.2614
# X23          0.265447   0.172967   1.535   0.1508
# X24          0.010247   0.101595   0.101   0.9213
# X25         -0.074284   0.092748  -0.801   0.4388
# X26          0.262160   0.144524   1.814   0.0948 .
# X27         -0.175838   0.062321  -2.821   0.0154 *
# X28          0.023655   0.071237   0.332   0.7456
# X29          0.061510   0.043840   1.403   0.1859
# X30          0.245576   0.217741   1.128   0.2814
# X31          0.005368   0.042011   0.128   0.9004
# X32          0.109102   0.183824   0.594   0.5639
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# ...

# %%
y1 = -0.01019  + 1.22080*X1 + -0.25079*X2 + -0.25079*X3 + -0.89935*X4 + 0.22237*X5 + -0.08937*X6 +-0.09139*X7 +-0.10070*X8 +-0.21980*X9 + -0.27418*X10 +  0.41778*X11 + 0.74020*X12 + 0.14433*X13 + 0.22531*X14 + -0.18507*X15 +  0.19632*X16 + -0.07415*X17 +1.05796*X18 + -0.13546*X19 + -0.07358*X20 + -0.61436*X21 +0.133417*X22 + 0.265447*X23 + 0.010247*X24 + -0.074284*X25 + 0.262160*X26 + -0.175838*X27 + 0.023655*X28 + 0.061510*X29 + 0.245576*X30 + 0.005368*X31 + 0.109102*X32

# %%
y
# Out:
#  [1] 0.00000000 0.04347826 0.08695652 0.13043478 0.17391304 0.21739130
#  [7] 0.26086957 0.30434783 0.34782609 0.39130435 0.43478261 0.47826087
# [13] 0.52173913 0.56521739 0.60869565 0.65217391 0.69565217 0.73913043
# [19] 0.78260870 0.82608696 0.86956522 0.91304348 0.95652174 1.00000000

# %%
y1
# Out:
#  [1] -0.01510868  0.07307485  0.13897351  0.26549171  0.32907859  0.42932999
#  [7]  0.50303711  0.57699829  0.68077989  0.78131961  0.87929247  0.95097861
# [13]  1.06543691  1.09221945  1.19990320  1.31810996  1.41246547  1.49825700
# [19]  1.57439709  1.66978955  1.73173890  1.81112139  1.91059667  1.96726054

# %%
year <- c(1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018)
year
# Out:
#  [1] 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009
# [16] 2010 2011 2012 2013 2014 2015 2016 2017 2018

# %%
data<-data.frame(y,y1)

# %%
plot(year, y, type="o", xlab="x", ylab="y",ylim=c(0,2) )
points(year, y1, col="green", pch="*")
lines(year,y1,lty=2,col="green")
legend(2556,400000,legend=c("total","predicted"), col=c("black","green"),pch=c("o","*"),lty=c(1,2), ncol=2)
# Out:
# plot without title

# %%
install.packages("Metrics")
library(Metrics)
mse(y, y1)
# Out:
# package 'Metrics' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\User\AppData\Local\Temp\Rtmp2hxRkb\downloaded_packages
# Warning message:
# "package 'Metrics' was built under R version 3.6.3"
# [1] 0.3374576

# %%
mae(y, y1)
# Out:
# [1] 0.4947816

# %%
rmse(y, y1)
# Out:
# [1] 0.580911

# %%
mape(y, y1)
# Out:
# [1] Inf

# %%
rss <- sum((y1 - y) ^ 2)  ## residual sum of squares
tss <- sum((y - mean(y)) ^ 2)  ## total sum of squares
rsq <- 1 - rss/tss
rsq
# Out:
# [1] -2.725532

# %%
df <- read.csv("ayutthaya.csv", sep=",", header=T,fileEncoding="UTF-8-BOM")
attach(df)
df
# Out:
# The following object is masked from df (pos = 4):
#
#     X
#    X    b        c     d    e      f    g   h    i     j     ... Life_Insurance
# 1  1995 143862.6  3069  471  70294 2030 254 1566 16137  1392 ...  48465
# 2  1996 171503.9  3305  513  80942 2290 324 5205 19161  1626 ...  61572
# 3  1997 179223.5  4056  474  86917 2697 382 1756 20641  2219 ...  74679
# 4  1998 180611.8  4805  395  84878 3388 420 1166 22362  2306 ...  87786
# 5  1999 189856.7  4030  302  92332 2974 503 1397 22431  2483 ... 100893
# 6  2000 219141.8  3854  255 107280 3169 590 1579 27786  2503 ... 114000
# 7  2001 219060.6  4577  271 108644 3266 609 1572 26871  2707 ... 127107
# 8  2002 231122.5  4704  248 117685 3440 545 1678 28811  3440 ... 116792
# 9  2003 256743.1  4892  248 138362 3860 952 1745 28845  3569 ... 127879
# 10 2004 271765.1  5797  537 146185 4317 916 2036 29309  3758 ... 109722
# 11 2005 273739.9  5903  586 149386 4430 710 2539 28303  3667 ... 132048
# ...

# %%
colnames(df, do.NULL = TRUE, prefix = "col")
# Out:
#  [1] "X"                 "b"                 "c"
#  [4] "d"                 "e"                 "f"
#  [7] "g"                 "h"                 "i"
# [10] "j"                 "k"                 "l"
# [13] "m"                 "n"                 "o"
# [16] "p"                 "q"                 "r"
# [19] "s"                 "t"                 "u"
# [22] "JURISTIC_PERSON"   "Tourism"           "Life_Insurance"
# [25] "Farm_holding"      "Births"            "Population"
# [28] "th_worker"         "debt"              "percent_import_us"
# [31] "population"        "Planted_area"      "export"

# %%
x1 <- c
x2 <- d
x3 <- e
x4 <- f
x5 <- g
x6 <- h
x7 <- i
x8 <- j
x9<- k
x10<-l
x11<- m
x12<- n
x13<- o
x14<- p
x15<- q
x16<- r
x17<- s
x18<- t
x19<- u
y <- b

# %%
model <- lm(y ~ X1+X2+X3+X4+X5+X6+X7+X8+X9+X10+X11+X12+X13+X14+X15+X16+X17+X18+X19)
summary(model)
# Out:
# Warning message in summary.lm(model):
# "essentially perfect fit: summary may be unreliable"
# Call:
# lm(formula = y ~ X1 + X2 + X3 + X4 + X5 + X6 + X7 + X8 + X9 +
#     X10 + X11 + X12 + X13 + X14 + X15 + X16 + X17 + X18 + X19)
#
# Residuals:
#          1          2          3          4          5          6          7
#  7.947e-12  1.303e-11 -8.712e-12 -1.378e-11  2.096e-12  3.748e-12  1.510e-12
#          8          9         10         11         12         13         14
# -8.093e-12 -6.383e-12  3.096e-11 -2.889e-11 -1.597e-12  1.384e-12  1.225e-11
#         15         16         17         18         19         20         21
# -1.036e-11 -1.611e-11  2.922e-11 -1.499e-11  1.178e-11  7.590e-12 -1.988e-11
#         22         23         24
# -3.601e-12  1.444e-11 -3.554e-12
#
# Coefficients:
#               Estimate Std. Error    t value Pr(>|t|)
# (Intercept)  1.439e+05  4.918e-11  2.925e+15   <2e-16 ***
# X1           3.245e+05  3.454e-09  9.394e+13   <2e-16 ***
# ...

# %%
# ayt2 = df[""]

# %%
model <- lm(y ~ X1+X2+X3+X4+X5+X6+X7+X8+X9+X10+X11+X12+X13+X14+X15+X16+X17+X18+X19+X20+X21+X22)
summary(model)
# Out:
# Warning message in summary.lm(model):
# "essentially perfect fit: summary may be unreliable"
# Call:
# lm(formula = y ~ X1 + X2 + X3 + X4 + X5 + X6 + X7 + X8 + X9 +
#     X10 + X11 + X12 + X13 + X14 + X15 + X16 + X17 + X18 + X19 +
#     X20 + X21 + X22)
#
# Residuals:
#          1          2          3          4          5          6          7
# -1.030e-12  5.971e-12 -1.708e-12 -1.180e-11  1.489e-11 -1.089e-11  2.035e-11
#          8          9         10         11         12         13         14
# -5.265e-12 -1.419e-11  1.752e-11 -1.311e-11 -3.708e-13 -5.487e-12  7.564e-12
#         15         16         17         18         19         20         21
# -7.965e-12  8.396e-13  4.600e-12 -5.285e-12  5.628e-13  8.012e-12 -8.263e-12
#         22         23         24
# -2.819e-14  8.336e-12 -3.249e-12
#
# Coefficients:
#               Estimate Std. Error    t value Pr(>|t|)
# (Intercept)  1.439e+05  7.175e-11  2.005e+15 3.17e-16 ***
# ...

# %%
# dfe<-data.frame(y=X1+X2+X3+X4+X5+X6+X7+X8+X9+X10+X11+X12+X13+X14+X15+X16+X17+X18+X19+X20+X21+X22+X23+X24+X25+X26+X27+X28+X29+X30+X31+X32)

# %%
# model <- lm(y~.,dfe)
# summary(model)

# %%
df2 <- read.csv("nor_ayu2.csv", sep=",", header=T, fileEncoding="UTF-8-BOM")

# %%
df2
# Out:
#    year       b          c          d           e          f          g
# 1  0.00000000 0.00000000 0.00000000 0.100631769 0.00000000 0.00000000 0.0000000
# 2  0.04347826 0.08519104 0.01840443 0.119584838 0.04791777 0.03399137 0.1002865
# 3  0.08695652 0.10898274 0.07697107 0.101985560 0.07480627 0.08720094 0.1833811
# 4  0.13043478 0.11326167 0.13538174 0.066335740 0.06563043 0.17753955 0.2378223
# 5  0.17391304 0.14175457 0.07494346 0.024368231 0.09917467 0.12341483 0.3567335
# 6  0.21739130 0.23201175 0.06121812 0.003158845 0.16644316 0.14890835 0.4813754
# 7  0.26086957 0.23176132 0.11760118 0.010379061 0.17258139 0.16158975 0.5085960
# 8  0.30434783 0.26893625 0.12750526 0.000000000 0.21326739 0.18433782 0.4169054
# 9  0.34782609 0.34789930 0.14216642 0.000000000 0.30631733 0.23924696 1.0000000
# 10 0.39130435 0.39419734 0.21274273 0.130415162 0.34152214 0.29899333 0.9484241
# 11 0.43478261 0.40028368 0.22100912 0.152527076 0.35592717 0.31376650 0.6532951
# ...

# %%
eFactor <- factor(df2$e)
anovaResult <- aov(df2$b~eFactor, data=df2)
summary(anovaResult)
# Out:
#             Df Sum Sq Mean Sq
# eFactor     23  2.696  0.1172

# %%
qtukey(1, nmeans=anovaResult$rank, df=anovaResult$df.residual, lower.tail=F)
# Out:
# Warning message in qtukey(1, nmeans = anovaResult$rank, df = anovaResult$df.residual, :
# "NaNs produced"
# [1] NaN

# %%
tk <- TukeyHSD(anovaResult, conf.level = 0.99)
plot(tk)
# Out:
# Warning message in qtukey(conf.level, length(means), x$df.residual):
# "NaNs produced"Warning message in min(x):
# "no non-missing arguments to min; returning Inf"Warning message in max(x):
# "no non-missing arguments to max; returning -Inf"
# Error in plot.window(...): need finite 'xlim' values
# Traceback:
#
# 1. plot(tk)
# 2. plot.TukeyHSD(tk)
# 3. plot(c(xi[, "lwr"], xi[, "upr"]), rep.int(yvals, 2L), type = "n",
#  .     axes = FALSE, xlab = "", ylab = "", main = NULL, ...)
# 4. plot.default(c(xi[, "lwr"], xi[, "upr"]), rep.int(yvals, 2L),
#  .     type = "n", axes = FALSE, xlab = "", ylab = "", main = NULL,
#  .     ...)
# 5. localWindow(xlim, ylim, log, asp, ...)
# 6. plot.window(...)
# plot without title
