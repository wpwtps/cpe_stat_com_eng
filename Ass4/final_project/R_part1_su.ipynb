# %%
getwd()
# Out:
# [1] "C:/Users/User/Documents/stat2020/final_project"

# %%
df <- read.csv("nor_sup.csv", sep=",", header=T,fileEncoding="UTF-8-BOM")
attach(df)
df
# Out:
# The following object is masked from df (pos = 3):
#
#     X
#
# The following objects are masked from df (pos = 4):
#
#     X, X0, X1, X10, X11, X12, X13, X14, X15, X16, X17, X18, X19, X2,
#     X20, X21, X22, X23, X24, X25, X26, X27, X28, X29, X3, X30, X31, X4,
#     X5, X6, X7, X8, X9
#    X  X0         X1         X2         X3         X4          X5
# 1   0 0.00000000 0.00000000 0.00000000 0.02623295 0.004159473 0.00000000
# 2   1 0.04347826 0.09435327 0.06484754 0.25666317 0.036336525 0.06660137
# 3   2 0.08695652 0.09743044 0.09242213 0.24616999 0.000000000 0.14593536
# 4   3 0.13043478 0.13027984 0.16454344 0.14165792 0.020326479 0.27228208
# 5   4 0.17391304 0.10534690 0.10754500 0.06736621 0.003060744 0.19784525
# 6   5 0.21739130 0.10008679 0.06595710 0.02014690 0.074478104 0.15279138
# 7   6 0.26086957 0.10040240 0.08765513 0.04218258 0.034845393 0.17042116
# 8   7 0.30434783 0.11943086 0.11185995 0.01217209 0.087348925 0.19196866
# ...

# %%
su = df[0:21]

# %%
su
# Out:
#    X  X0         X1         X2         X3         X4          X5
# 1   0 0.00000000 0.00000000 0.00000000 0.02623295 0.004159473 0.00000000
# 2   1 0.04347826 0.09435327 0.06484754 0.25666317 0.036336525 0.06660137
# 3   2 0.08695652 0.09743044 0.09242213 0.24616999 0.000000000 0.14593536
# 4   3 0.13043478 0.13027984 0.16454344 0.14165792 0.020326479 0.27228208
# 5   4 0.17391304 0.10534690 0.10754500 0.06736621 0.003060744 0.19784525
# 6   5 0.21739130 0.10008679 0.06595710 0.02014690 0.074478104 0.15279138
# 7   6 0.26086957 0.10040240 0.08765513 0.04218258 0.034845393 0.17042116
# 8   7 0.30434783 0.11943086 0.11185995 0.01217209 0.087348925 0.19196866
# 9   8 0.34782609 0.20236968 0.19244678 0.02014690 0.259142992 0.24387855
# 10  9 0.39130435 0.24435853 0.26123942 0.02833158 0.175796578 0.31733595
# 11 10 0.43478261 0.26754248 0.25191091 0.00000000 0.201302778 0.32908913
# 12 11 0.47826087 0.35455789 0.33036081 0.08856243 0.301208601 0.41038198
# ...

# %%
x1 <- X1
x2 <- X2
x3 <- X3
x4 <- X4
x5 <- X5
x6 <- X6
x7 <- X7
x8 <- X8
x9<- X9
x10<-X10
x11<- X11
x12<- X12
x13<- X13
x14<- X14
x15<- X15
x16<- X16
x17<- X17
x18<- X18
x19<- X19
X20<- X20
X21<- X21
x22<- X22
x23<- X23
x24<- X24
x25<- X25
x26<- X26
x27<- X27
x28<- X28
x29<- X29
x30<-X30
x31<- X31

y <- X0

# %%
model <- lm(y ~ X1+X2+X3+X4+X5+X6+X7+X8+X9+X10+X11+X12+X13+X14+X15+X16+X17+X18+X19)
summary(model)
# Out:
# Call:
# lm(formula = y ~ X1 + X2 + X3 + X4 + X5 + X6 + X7 + X8 + X9 +
#     X10 + X11 + X12 + X13 + X14 + X15 + X16 + X17 + X18 + X19)
#
# Residuals:
#          1          2          3          4          5          6          7
#  0.0023020  0.0055983 -0.0115526 -0.0041087  0.0025651  0.0087464 -0.0022525
#          8          9         10         11         12         13         14
# -0.0126869  0.0033995  0.0124904 -0.0077977 -0.0029511  0.0021568  0.0034305
#         15         16         17         18         19         20         21
#  0.0008224  0.0072286 -0.0062631 -0.0045098  0.0028340 -0.0004124  0.0022960
#         22         23         24
#  0.0034246 -0.0032345 -0.0015253
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.040199   0.065362  -0.615   0.5718
# X1          -3.203210   2.547673  -1.257   0.2770
# X2           1.160715   0.999718   1.161   0.3102
# X3           0.307338   0.204420   1.503   0.2071
# ...

# %%
model <- lm(y ~ X20+X21+X22+X23+X24+X25+X26+X27+X28+X29+X30+X31)
summary(model)
# Out:
# Call:
# lm(formula = y ~ X20 + X21 + X22 + X23 + X24 + X25 + X26 + X27 +
#     X28 + X29 + X30 + X31)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.038645 -0.004305 -0.001475  0.008280  0.041469
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.048982   0.036263  -1.351  0.20391
# X20          0.170576   0.079730   2.139  0.05566 .
# X21         -0.033030   0.039991  -0.826  0.42640
# X22         -0.022455   0.045203  -0.497  0.62915
# X23         -0.034320   0.045374  -0.756  0.46532
# X24          0.003088   0.027726   0.111  0.91333
# X25         -0.052022   0.042243  -1.231  0.24381
# X26         -0.115208   0.076400  -1.508  0.15973
# X27         -0.058493   0.055142  -1.061  0.31153
# X28          0.073199   0.036338   2.014  0.06908 .
# X29          0.880219   0.202031   4.357  0.00114 **
# X30         -0.040618   0.038289  -1.061  0.31150
# X31          0.156187   0.151674   1.030  0.32524
# ---
# ...

# %%
y1 = 0.040199   + -3.203210*X1 + 1.160715*X2 + 0.307338*X3 + 0.711930*X4 + -0.125830*X5 + 0.058882*X6 + -0.005698*X7 + 0.582502*X8 + 0.027606*X9 +  -0.087029*X10 +  -0.018447 *X11 + 0.321905*X12 + 0.090019*X13 + -0.050209*X14 + -0.042639*X15 +  0.143815*X16 + 0.446277*X17 +1.309311*X18 + 0.015525*X19 + 0.170576*X20 + -0.033030*X21 + -0.022455*X22 + -0.034320*X23 + 0.003088*X24 + -0.052022*X25 + -0.115208*X26 + -0.058493*X27 + 0.073199*X28 + 0.880219*X29 + -0.040618*X30 +  0.156187*X31

# %%
y
# Out:
#  [1] 0.00000000 0.04347826 0.08695652 0.13043478 0.17391304 0.21739130
#  [7] 0.26086957 0.30434783 0.34782609 0.39130435 0.43478261 0.47826087
# [13] 0.52173913 0.56521739 0.60869565 0.65217391 0.69565217 0.73913043
# [19] 0.78260870 0.82608696 0.86956522 0.91304348 0.95652174 1.00000000

# %%
y1
# Out:
#  [1] 0.1110577 0.2130839 0.3073024 0.4147215 0.4673569 0.5589635 0.6553560
#  [8] 0.7380850 0.8233769 0.8890057 1.0310623 1.0688895 1.1924404 1.2583863
# [15] 1.3471524 1.4304514 1.5207815 1.6507943 1.6801449 1.7995483 1.8715746
# [22] 1.9466753 2.0394563 2.0894372

# %%
year <- c(1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018)
year
# Out:
#  [1] 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009
# [16] 2010 2011 2012 2013 2014 2015 2016 2017 2018

# %%
data<-data.frame(y,y1)

# %%
plot(year, y, type="o", xlab="x", ylab="y",ylim=c(0,2) )
points(year, y1, col="green", pch="*")
lines(year,y1,lty=2,col="green")
legend(2556,400000,legend=c("total","predicted"), col=c("black","green"),pch=c("o","*"),lty=c(1,2), ncol=2)
# Out:
# plot without title

# %%
df <- read.csv("suphan.csv", sep=",", header=T,fileEncoding="UTF-8-BOM")
attach(df)
df
# Out:
# The following object is masked from df (pos = 3):
#
#     X
#    X    b      c     d    e     f    g   h    i     j    ... Farm_holding
# 1  1995  31184  7594 1365  3124  434  77 1956  3706  614 ...  924530
# 2  1996  38359  9172 2463  3534  502  84 2854  4440  874 ...  916090
# 3  1997  38593  9843 2413  3071  583  97 2256  4825  770 ...  911272
# 4  1998  41091 11598 1915  3330  712 116 1847  4712  988 ...  904415
# 5  1999  39195 10211 1561  3110  636 144 1800  4679  949 ...  902341
# 6  2000  38795  9199 1336  4020  590 176 1780  4400  957 ...  930000
# 7  2001  38819  9727 1441  3515  608 152 1577  4143 1008 ... 1799671
# 8  2002  40266 10316 1298  4184  630 131 1247  4188  796 ... 1101930
# 9  2003  46573 12277 1336  6373  683 132 1105  4551  831 ... 1878574
# 10 2004  49766 13951 1375  5311  758 133 1404  4925  861 ... 1273860
# 11 2005  51529 13724 1240  5636  770 179 1476  4984  860 ... 1359825
# 12 2006  58146 15633 1662  6909  853 184 1567  5599 1007 ... 2316016
# ...

# %%
colnames(df, do.NULL = TRUE, prefix = "col")
# Out:
#  [1] "X"                 "b"                 "c"
#  [4] "d"                 "e"                 "f"
#  [7] "g"                 "h"                 "i"
# [10] "j"                 "k"                 "l"
# [13] "m"                 "n"                 "o"
# [16] "p"                 "q"                 "r"
# [19] "s"                 "t"                 "u"
# [22] "worker"            "Farm_holding"      "New_Construction"
# [25] "tourist"           "sup_pop"           "th_worker"
# [28] "debt"              "percent_import_us" "population"
# [31] "Planted_area"      "export"

# %%
x1 <- c
x2 <- d
x3 <- e
x4 <- f
x5 <- g
x6 <- h
x7 <- i
x8 <- j
x9<- k
x10<-l
x11<- m
x12<- n
x13<- o
x14<- p
x15<- q
x16<- r
x17<- s
x18<- t
x19<- u
y <- b

# %%
model <- lm(y ~ X1+X2+X3+X4+X5+X6+X7+X8+X9+X10+X11+X12+X13+X14+X15+X16+X17+X18+X19)
summary(model)
# Out:
# Warning message in summary.lm(model):
# "essentially perfect fit: summary may be unreliable"
# Call:
# lm(formula = y ~ X1 + X2 + X3 + X4 + X5 + X6 + X7 + X8 + X9 +
#     X10 + X11 + X12 + X13 + X14 + X15 + X16 + X17 + X18 + X19)
#
# Residuals:
#          1          2          3          4          5          6          7
#  3.927e-12 -3.566e-12 -7.734e-13 -1.934e-12  1.651e-13  1.703e-13  6.185e-12
#          8          9         10         11         12         13         14
# -5.498e-12 -1.850e-12  4.858e-12 -5.413e-12  6.276e-12 -4.787e-12  6.748e-13
#         15         16         17         18         19         20         21
#  2.230e-12 -5.491e-14 -3.202e-13 -1.058e-12  1.857e-13  3.617e-14  1.476e-12
#         22         23         24
#  1.791e-12 -3.490e-12  7.689e-13
#
# Coefficients:
#               Estimate Std. Error    t value Pr(>|t|)
# (Intercept)  3.118e+04  3.526e-11  8.844e+14   <2e-16 ***
# X1           7.604e+04  1.374e-09  5.533e+13   <2e-16 ***
# ...

# %%
ayt2 = df[""]
