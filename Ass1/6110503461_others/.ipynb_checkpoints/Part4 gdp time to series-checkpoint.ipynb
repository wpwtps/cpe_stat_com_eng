# %%
import os
os.chdir('C:\\Users\\User\\Documents\\stat2020\\Week2_data\\transportation')
os.getcwd()
# Out:
# 'C:\\Users\\User\\Documents\\stat2020\\Week2_data\\transportation'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.offline as pyo
import plotly.graph_objs as go
# %matplotlib inline

# %%
gdp = pd.read_excel('gdp_per_capita.xlsx',sheet_name='Data')
gdp
# Out:
#                                           Series Name     Series Code  \
# 0                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 1                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 2                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 3                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 4                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# ..                                                ...             ...
# 217                                               NaN             NaN
# 218                                               NaN             NaN
# 219                                               NaN             NaN
# 220  Data from database: World Development Indicators             NaN
# 221                          Last Updated: 10/28/2019             NaN
#
#        Country Name Country Code 1990 [YR1990] 2000 [YR2000] 2010 [YR2010]  \
# ...

# %%
gdp.drop([217, 218, 219, 220, 221], inplace=True)
gdp
# Out:
#                       Series Name     Series Code           Country Name  \
# 0    GDP per capita (current US$)  NY.GDP.PCAP.CD            Afghanistan
# 1    GDP per capita (current US$)  NY.GDP.PCAP.CD                Albania
# 2    GDP per capita (current US$)  NY.GDP.PCAP.CD                Algeria
# 3    GDP per capita (current US$)  NY.GDP.PCAP.CD         American Samoa
# 4    GDP per capita (current US$)  NY.GDP.PCAP.CD                Andorra
# ..                            ...             ...                    ...
# 212  GDP per capita (current US$)  NY.GDP.PCAP.CD  Virgin Islands (U.S.)
# 213  GDP per capita (current US$)  NY.GDP.PCAP.CD     West Bank and Gaza
# 214  GDP per capita (current US$)  NY.GDP.PCAP.CD            Yemen, Rep.
# 215  GDP per capita (current US$)  NY.GDP.PCAP.CD                 Zambia
# 216  GDP per capita (current US$)  NY.GDP.PCAP.CD               Zimbabwe
#
#     Country Code 1990 [YR1990] 2000 [YR2000] 2010 [YR2010] 2011 [YR2011]  \
# ...

# %%
gdp2 = gdp.drop(['Series Name','Series Code','Country Code','Country Code'], axis=1)
gdp2
# Out:
#               Country Name 1990 [YR1990] 2000 [YR2000] 2010 [YR2010]  \
# 0              Afghanistan            ..            ..       543.303
# 1                  Albania        617.23       1126.68       4094.36
# 2                  Algeria       2408.69       1765.02       4480.79
# 3           American Samoa            ..            ..       10271.2
# 4                  Andorra       18878.5       21936.5       39736.4
# ..                     ...           ...           ...           ...
# 212  Virgin Islands (U.S.)            ..            ..       40043.2
# 213     West Bank and Gaza            ..       1476.17       2354.13
# 214            Yemen, Rep.       482.248       554.449       1334.78
# 215                 Zambia        408.77        345.69       1489.46
# 216               Zimbabwe       841.973       563.058       948.332
#
#     2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015]  \
# ...

# %%
gdp2.replace({'..':np.nan}, inplace=True)
gdp2.head()
# Out:
#      Country Name  1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  2011 [YR2011]  \
# 0     Afghanistan            NaN            NaN     543.303042     591.162346
# 1         Albania     617.230436    1126.683318    4094.358816    4437.177794
# 2         Algeria    2408.688815    1765.022577    4480.785777    5455.842310
# 3  American Samoa            NaN            NaN   10271.224523   10294.302265
# 4         Andorra   18878.505969   21936.530101   39736.354063   41100.729938
#
#    2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  \
# 0     641.872034     637.165044     613.856333     578.466353     547.228110
# 1    4247.614342    4413.082887    4578.667934    3952.830781    4124.108543
# 2    5592.221910    5499.587764    5493.056772    4177.888966    3948.811897
# 3   11568.793001   11505.393714   11525.156387   11843.331183   11714.895678
# 4   38392.943901   40626.751632   42300.334128   36039.653496   37224.108916
#
# ...

# %%
sns.heatmap(gdp2.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
gdp2.drop(['2019 [YR2019]'],axis=1, inplace=True)
gdp2.head()
# Out:
#      Country Name  1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  2011 [YR2011]  \
# 0     Afghanistan            NaN            NaN     543.303042     591.162346
# 1         Albania     617.230436    1126.683318    4094.358816    4437.177794
# 2         Algeria    2408.688815    1765.022577    4480.785777    5455.842310
# 3  American Samoa            NaN            NaN   10271.224523   10294.302265
# 4         Andorra   18878.505969   21936.530101   39736.354063   41100.729938
#
#    2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  \
# 0     641.872034     637.165044     613.856333     578.466353     547.228110
# 1    4247.614342    4413.082887    4578.667934    3952.830781    4124.108543
# 2    5592.221910    5499.587764    5493.056772    4177.888966    3948.811897
# 3   11568.793001   11505.393714   11525.156387   11843.331183   11714.895678
# 4   38392.943901   40626.751632   42300.334128   36039.653496   37224.108916
#
#    2017 [YR2017]  2018 [YR2018]
# ...

# %%
regions = pd.read_excel('countries_regions.xlsx')
regions.head()
# Out:
#       CountryName                 Region  ThirdWorld
# 0     Afghanistan             South Asia           1
# 1         Albania         Eastern Europe           0
# 2         Algeria                 Africa           0
# 3  American Samoa  Australia and Oceanea           0
# 4         Andorra         Western Europe           0

# %%
regions.drop(['ThirdWorld'],axis=1, inplace=True)
regions.head()
# Out:
#       CountryName                 Region
# 0     Afghanistan             South Asia
# 1         Albania         Eastern Europe
# 2         Algeria                 Africa
# 3  American Samoa  Australia and Oceanea
# 4         Andorra         Western Europe

# %%
reggdp = regions.set_index('CountryName').join(gdp2.set_index('Country Name'))

reggdp
# Out:
#                                       Region  1990 [YR1990]  2000 [YR2000]  \
# CountryName
# Afghanistan                       South Asia            NaN            NaN
# Albania                       Eastern Europe     617.230436    1126.683318
# Algeria                               Africa    2408.688815    1765.022577
# American Samoa         Australia and Oceanea            NaN            NaN
# Andorra                       Western Europe   18878.505969   21936.530101
# ...                                      ...            ...            ...
# Virgin Islands (U.S.)          North America            NaN            NaN
# West Bank and Gaza               Middle East            NaN    1476.171850
# Yemen, Rep.                      Middle East     482.247874     554.448633
# Zambia                                Africa     408.769535     345.689554
# Zimbabwe                              Africa     841.972990     563.057741
#
# ...

# %%
cgdp = reggdp.dropna()
cgdp
# Out:
#                                     Region  1990 [YR1990]  2000 [YR2000]  \
# CountryName
# Albania                     Eastern Europe     617.230436    1126.683318
# Algeria                             Africa    2408.688815    1765.022577
# Andorra                     Western Europe   18878.505969   21936.530101
# Angola                              Africa     947.704182     556.836318
# Antigua and Barbuda          North America    7348.212943   10920.842688
# ...                                    ...            ...            ...
# Vanuatu              Australia and Oceanea    1080.672450    1470.572265
# Vietnam                     Southeast Asia      95.188250     390.093326
# Yemen, Rep.                    Middle East     482.247874     554.448633
# Zambia                              Africa     408.769535     345.689554
# Zimbabwe                            Africa     841.972990     563.057741
#
#                      2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  \
# ...

# %%
cgdp.groupby(by="Region").mean()
# Out:
#                        1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  \
# Region
# Africa                   1094.300126    1156.795707    2695.770829
# Australia and Oceanea    3596.096243    4229.061746    9410.991906
# East Asia                9369.982342   15563.326682   26431.921560
# Eastern Europe           2792.538084    3187.283731    9962.989057
# Middle East              8495.305080   13295.567919   23669.806299
# North America            4698.724164    7313.129904   11728.010282
# Northern Europe         24611.091539   29816.271469   53566.706038
# South America            1875.224849    3177.907052    7283.199484
# South Asia                461.374688     779.676329    2272.720559
# Southeast Asia           4215.779247    6920.417772   14178.855584
# Thailand                 1508.942737    2007.736363    5076.342992
# Western Asia              970.162006     609.523435    3581.383063
# Western Europe          18731.471475   21575.260970   42669.822804
#
# ...

# %%
cgdp.to_csv('cgdp2.csv',index=False)

# %%
df = pd.read_csv('cgdp2.csv',sep=',', header='infer')
dff2 = df.rename(columns={"Region": "Year"})
dff2
# Out:
#                       Year  1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  \
# 0           Eastern Europe     617.230436    1126.683318    4094.358816
# 1                   Africa    2408.688815    1765.022577    4480.785777
# 2           Western Europe   18878.505969   21936.530101   39736.354063
# 3                   Africa     947.704182     556.836318    3587.883798
# 4            North America    7348.212943   10920.842688   13092.073818
# ..                     ...            ...            ...            ...
# 160  Australia and Oceanea    1080.672450    1470.572265    2966.857116
# 161         Southeast Asia      95.188250     390.093326    1317.890706
# 162            Middle East     482.247874     554.448633    1334.784845
# 163                 Africa     408.769535     345.689554    1489.459070
# 164                 Africa     841.972990     563.057741     948.331854
#
#      2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  \
# ...

# %%
df2 =dff2.set_index('Year')
meandf2 = df2.groupby(by="Year").mean()
meandf2
# Out:
#                        1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  \
# Year
# Africa                   1094.300126    1156.795707    2695.770829
# Australia and Oceanea    3596.096243    4229.061746    9410.991906
# East Asia                9369.982342   15563.326682   26431.921560
# Eastern Europe           2792.538084    3187.283731    9962.989057
# Middle East              8495.305080   13295.567919   23669.806299
# North America            4698.724164    7313.129904   11728.010282
# Northern Europe         24611.091539   29816.271469   53566.706038
# South America            1875.224849    3177.907052    7283.199484
# South Asia                461.374688     779.676329    2272.720559
# Southeast Asia           4215.779247    6920.417772   14178.855584
# Thailand                 1508.942737    2007.736363    5076.342992
# Western Asia              970.162006     609.523435    3581.383063
# Western Europe          18731.471475   21575.260970   42669.822804
#
# ...

# %%
df_trans = meandf2.T

# %%
df_trans
# Out:
# Year                Africa  Australia and Oceanea     East Asia  \
# 1990 [YR1990]  1094.300126            3596.096243   9369.982342
# 2000 [YR2000]  1156.795707            4229.061746  15563.326682
# 2010 [YR2010]  2695.770829            9410.991906  26431.921560
# 2011 [YR2011]  2923.968542           11015.226163  30568.391699
# 2012 [YR2012]  3085.442749           11744.046206  32775.631467
# 2013 [YR2013]  3087.268665           11993.754579  34242.069947
# 2014 [YR2014]  3014.180151           11703.536059  35303.843769
# 2015 [YR2015]  2535.072174           10604.439682  31892.398095
# 2016 [YR2016]  2451.782008           10186.445877  32638.454391
# 2017 [YR2017]  2626.306820           10859.337687  34655.865813
# 2018 [YR2018]  2758.033681           11179.518425  36599.455428
#
# Year           Eastern Europe   Middle East  North America  Northern Europe  \
# 1990 [YR1990]     2792.538084   8495.305080    4698.724164     24611.091539
# ...

# %%
sns.lineplot(data=df_trans)
locs, labels = plt.xticks()
plt.setp(labels, rotation=45)

plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
