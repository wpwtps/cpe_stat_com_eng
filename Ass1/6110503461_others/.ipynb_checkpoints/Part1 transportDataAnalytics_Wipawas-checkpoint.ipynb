# %%
import os
os.chdir('C:\\Users\\User\\Documents\\stat2020\\Week2_data\\transportation')
os.getcwd()
# Out:
# 'C:\\Users\\User\\Documents\\stat2020\\Week2_data\\transportation'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('air_rail_gas_2012_2016.csv',sep=',', header='infer')
df.head()
# Out:
#   CountryName          Region  ThirdWorld   airtrans2012  airtrans2016  \
# 0     Algeria          Africa           0   54292.000000       73465.0
# 1     Austria  Western Europe           0  162715.735981      149030.0
# 2  Azerbaijan    Western Asia           0   16597.000000       24009.0
# 3     Belarus  Eastern Europe           0   14608.000000       26857.0
# 4     Belgium  Western Europe           0  132099.342542      147324.0
#
#    railLines2012  railLines2016  gasPrice2012  gasPrice2016
# 0         4175.0        3843.17          0.17          0.17
# 1         4985.0        4917.00          1.81          1.15
# 2         2068.1        2074.00          0.57          0.35
# 3         5462.0        5459.00          0.90          0.62
# 4         3592.0        3602.00          1.98          1.32

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        ThirdWorld  airtrans2012  airtrans2016  railLines2012  railLines2016  \
# count   51.000000  5.100000e+01  5.100000e+01      51.000000      51.000000
# mean     0.019608  4.481529e+05  4.971618e+05   13149.238078   14026.041157
# std      0.140028  1.427421e+06  1.448869e+06   26544.855304   26783.889739
# min      0.000000  4.150000e+02  8.500000e+01     239.200000     249.000000
# 25%      0.000000  1.671900e+04  1.965550e+04    1865.500000    2091.500000
# 50%      0.000000  5.429200e+04  7.318800e+04    3641.000000    3843.170000
# 75%      0.000000  2.711166e+05  3.610930e+05   10209.500000   11800.700000
# max      1.000000  9.864360e+06  9.640591e+06  153516.600000  151270.000000
#
#        gasPrice2012  gasPrice2016
# count     51.000000     51.000000
# mean       1.432431      0.945608
# std        0.541753      0.328142
# min        0.124000      0.170000
# 25%        1.025000      0.710000
# 50%        1.640000      1.050000
# 75%        1.805000      1.200000
# ...

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'ThirdWorld'}>,
#         <AxesSubplot:title={'center':'airtrans2012'}>,
#         <AxesSubplot:title={'center':'airtrans2016'}>],
#        [<AxesSubplot:title={'center':'railLines2012'}>,
#         <AxesSubplot:title={'center':'railLines2016'}>,
#         <AxesSubplot:title={'center':'gasPrice2012'}>],
#        [<AxesSubplot:title={'center':'gasPrice2016'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df.hist(column='airtrans2016')
# Out:
# array([[<AxesSubplot:title={'center':'airtrans2016'}>]], dtype=object)

# %%
sns.distplot(df['airtrans2016'], hist=True, kde=False, rug=False)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='airtrans2016'>

# %%
sns.distplot(df['airtrans2016'], hist=True, kde=True, rug=False)
# Out:
# <AxesSubplot:xlabel='airtrans2016', ylabel='Density'>

# %%
sns.distplot(df['airtrans2016'], hist=False, kde=True, rug=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='airtrans2016', ylabel='Density'>

# %%
df.Region.unique()
# Out:
# array(['Africa', 'Western Europe', 'Western Asia', 'Eastern Europe',
#        'North America', 'East Asia', 'Northern Europe', 'South Asia',
#        'Middle East', 'Southeast Asia'], dtype=object)

# %%
df[df.Region=='Africa']
# Out:
#          CountryName  Region  ThirdWorld  airtrans2012  airtrans2016  \
# 0            Algeria  Africa           0  54292.000000       73465.0
# 8   Congo, Dem. Rep.  Africa           1   4781.000000       11513.0
# 9      Cote d'Ivoire  Africa           0    415.000000        9463.0
# 15             Gabon  Africa           0   1553.000000        2305.0
# 32           Morocco  Africa           0  61161.300702       80085.0
# 43           Tunisia  Africa           0  37233.000000       38631.0
#
#     railLines2012  railLines2016  gasPrice2012  gasPrice2016
# 0          4175.0        3843.17          0.17          0.17
# 8          3641.0        3641.00          1.48          1.20
# 9           639.0         639.00          1.20          0.93
# 15          810.0         810.00          0.91          0.79
# 32         2109.0        2109.00          0.96          0.86
# 43         1867.0        2244.00          0.69          0.62

# %%
df[df.Region=='Western Europe']
# Out:
#        CountryName          Region  ThirdWorld   airtrans2012  airtrans2016  \
# 1          Austria  Western Europe           0  162715.735981      149030.0
# 4          Belgium  Western Europe           0  132099.342542      147324.0
# 11  Czech Republic  Western Europe           0   44189.000000       43878.0
# 14          France  Western Europe           0  739353.599757      599427.0
# 17         Germany  Western Europe           0  985668.769188      962803.0
# 28      Luxembourg  Western Europe           0   43021.000000       48255.0
# 34        Portugal  Western Europe           0  131870.000000      154448.0
# 39        Slovenia  Western Europe           0   18141.000000       17825.0
# 40           Spain  Western Europe           0  471440.886886      566775.0
# 42     Switzerland  Western Europe           0  257233.254296      229530.0
#
#     railLines2012  railLines2016  gasPrice2012  gasPrice2016
# 1        4985.000       4917.000          1.81          1.15
# ...

# %%
df[df.Region=='Eastern Europe']
# Out:
#            CountryName          Region  ThirdWorld   airtrans2012  \
# 3              Belarus  Eastern Europe           0   14608.000000
# 5             Bulgaria  Eastern Europe           0   11826.000000
# 10             Croatia  Eastern Europe           0   26456.000000
# 18              Greece  Eastern Europe           0  111870.000000
# 19             Hungary  Eastern Europe           0   88801.831651
# 29             Moldova  Eastern Europe           0    6560.000000
# 31          Montenegro  Eastern Europe           0    7485.000000
# 33              Poland  Eastern Europe           0   81194.000000
# 35             Romania  Eastern Europe           0   51685.000000
# 36  Russian Federation  Eastern Europe           0  636748.000000
# 37              Serbia  Eastern Europe           0   16841.000000
# 38     Slovak Republic  Eastern Europe           0    1439.000000
# 46             Ukraine  Eastern Europe           0   73378.942618
#
# ...

# %%
df[df.Region=='North America']
# Out:
#       CountryName         Region  ThirdWorld  airtrans2012  airtrans2016  \
# 6          Canada  North America           0  1.280198e+06     1359442.0
# 48  United States  North America           0  9.864360e+06     9640591.0
#
#     railLines2012  railLines2016  gasPrice2012  gasPrice2016
# 6           254.6        48498.4          1.23          0.73
# 48       153516.6       151270.0          1.05          0.65

# %%
df[df.Region=='East Asia']
# Out:
#     CountryName     Region  ThirdWorld  airtrans2012  airtrans2016  \
# 7         China  East Asia           0  2.779741e+06     3952098.0
# 23        Japan  East Asia           0  8.746770e+05      984320.0
# 25  Korea, Rep.  East Asia           0  2.850000e+05      473606.0
# 30     Mongolia  East Asia           0  9.611028e+03        6009.0
#
#     railLines2012  railLines2016  gasPrice2012  gasPrice2016
# 7         66298.0        67092.0          1.28          0.81
# 23        19435.4        12835.4          1.61          0.88
# 25         3650.1         4071.0          1.63          1.05
# 30         1810.0         1810.0          1.22          0.67

# %%
df[df.Region=='Northern Europe']
# Out:
#        CountryName           Region  ThirdWorld  airtrans2012  airtrans2016  \
# 12         Estonia  Northern Europe           0  2.677800e+04       16179.0
# 13         Finland  Northern Europe           0  1.389141e+05      162119.0
# 22         Ireland  Northern Europe           0  6.488177e+05      836293.0
# 26          Latvia  Northern Europe           0  4.673200e+04       42392.0
# 27       Lithuania  Northern Europe           0  1.187400e+04        9719.0
# 47  United Kingdom  Northern Europe           0  1.050703e+06     1180312.0
#
#     railLines2012  railLines2016  gasPrice2012  gasPrice2016
# 12          792.0         1034.0          1.76          1.14
# 13         5944.0         5926.0          1.95          1.34
# 22         1919.0         2174.0          1.98          1.29
# 26         1864.0         1859.6          1.77          1.07
# 27         1767.0         1911.0          1.70          1.05
# 47        15846.5        16257.0          2.27          1.49

# %%
df[df.Region=='South Asia']
# Out:
#    CountryName      Region  ThirdWorld   airtrans2012  airtrans2016  \
# 20       India  South Asia           0  678125.937793      917625.0
# 41   Sri Lanka  South Asia           0   31373.000000       40711.0
#
#     railLines2012  railLines2016  gasPrice2012  gasPrice2016
# 20       64600.00      66687.000          0.86          0.81
# 41        1148.11       1561.706          0.93          0.65

# %%
df[df.Region=='Western Asia']
# Out:
#      CountryName        Region  ThirdWorld  airtrans2012  airtrans2016  \
# 2     Azerbaijan  Western Asia           0  16597.000000       24009.0
# 16       Georgia  Western Asia           0   3326.000000        3199.0
# 24    Kazakhstan  Western Asia           0  44580.000000       73188.0
# 45  Turkmenistan  Western Asia           0   1440.732194       12890.0
# 49    Uzbekistan  Western Asia           0  24328.000000       21486.0
#
#     railLines2012  railLines2016  gasPrice2012  gasPrice2016
# 2          2068.1         2074.0          0.57          0.35
# 16         1577.6         1415.0          1.37          0.74
# 24        14758.9        15529.0          0.67          0.40
# 45         3115.0         3115.0          0.20          0.27
# 49         4192.0         4304.0          0.87          1.28

# %%
df[df.Region=='Middle East']
# Out:
#            CountryName       Region  ThirdWorld   airtrans2012  airtrans2016  \
# 21  Iran, Islamic Rep.  Middle East           0  153142.822224      159754.0
# 44              Turkey  Middle East           0  476115.000000      743673.0
#
#     railLines2012  railLines2016  gasPrice2012  gasPrice2016
# 21         8368.0         8576.0         0.124         0.216
# 44         9642.0        10131.0         2.330         1.230

# %%
df[df.Region =='Middle East'].describe()
# Out:
#        ThirdWorld   airtrans2012   airtrans2016  railLines2012  railLines2016  \
# count         2.0       2.000000       2.000000       2.000000       2.000000
# mean          0.0  314628.911112  451713.500000    9005.000000    9353.500000
# std           0.0  228375.817040  412893.084564     900.854039    1099.551045
# min           0.0  153142.822224  159754.000000    8368.000000    8576.000000
# 25%           0.0  233885.866668  305733.750000    8686.500000    8964.750000
# 50%           0.0  314628.911112  451713.500000    9005.000000    9353.500000
# 75%           0.0  395371.955556  597693.250000    9323.500000    9742.250000
# max           0.0  476115.000000  743673.000000    9642.000000   10131.000000
#
#        gasPrice2012  gasPrice2016
# count      2.000000      2.000000
# mean       1.227000      0.723000
# std        1.559878      0.717006
# min        0.124000      0.216000
# 25%        0.675500      0.469500
# 50%        1.227000      0.723000
# ...

# %%
df[df.Region=='Southeast Asia']
# Out:
#    CountryName          Region  ThirdWorld   airtrans2012  airtrans2016  \
# 50     Vietnam  Southeast Asia           0  135300.414089      248580.0
#
#     railLines2012  railLines2016  gasPrice2012  gasPrice2016
# 50         2347.0         2581.0          1.06          0.59

# %%
df[df.Region=='North America'].hist()
# Out:
# array([[<AxesSubplot:title={'center':'ThirdWorld'}>,
#         <AxesSubplot:title={'center':'airtrans2012'}>,
#         <AxesSubplot:title={'center':'airtrans2016'}>],
#        [<AxesSubplot:title={'center':'railLines2012'}>,
#         <AxesSubplot:title={'center':'railLines2016'}>,
#         <AxesSubplot:title={'center':'gasPrice2012'}>],
#        [<AxesSubplot:title={'center':'gasPrice2016'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df['airtrans2016']
# Out:
# 0       73465.0
# 1      149030.0
# 2       24009.0
# 3       26857.0
# 4      147324.0
# 5       12187.0
# 6     1359442.0
# 7     3952098.0
# 8       11513.0
# 9        9463.0
# 10      26171.0
# 11      43878.0
# 12      16179.0
# 13     162119.0
# 14     599427.0
# 15       2305.0
# 16       3199.0
# 17     962803.0
# 18     128454.0
# 19     137605.0
# 20     917625.0
# 21     159754.0
# 22     836293.0
# 23     984320.0
# 24      73188.0
# 25     473606.0
# 26      42392.0
# 27       9719.0
# 28      48255.0
# 29       9625.0
# 30       6009.0
# 31       6842.0
# 32      80085.0
# 33      84075.0
# 34     154448.0
# 35      46733.0
# 36     746446.0
# 37      31958.0
# 38         85.0
# 39      17825.0
# 40     566775.0
# 41      40711.0
# 42     229530.0
# 43      38631.0
# 44     743673.0
# 45      12890.0
# 46      55261.0
# 47    1180312.0
# 48    9640591.0
# 49      21486.0
# 50     248580.0
# Name: airtrans2016, dtype: float64

# %%
sns.boxplot(x='airtrans2016', data=df)
# Out:
# <AxesSubplot:xlabel='airtrans2016'>

# %%
sns.boxplot(x='Region',y='gasPrice2012', data=df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='gasPrice2012'>

# %%
chart = sns.boxplot(x='Region',y='gasPrice2012', data=df)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Africa'),
#  Text(1, 0, 'Western Europe'),
#  Text(2, 0, 'Western Asia'),
#  Text(3, 0, 'Eastern Europe'),
#  Text(4, 0, 'North America'),
#  Text(5, 0, 'East Asia'),
#  Text(6, 0, 'Northern Europe'),
#  Text(7, 0, 'South Asia'),
#  Text(8, 0, 'Middle East'),
#  Text(9, 0, 'Southeast Asia')]

# %%
chart = sns.boxplot(x='Region',y='railLines2016', data=df, showfliers=False)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Africa'),
#  Text(1, 0, 'Western Europe'),
#  Text(2, 0, 'Western Asia'),
#  Text(3, 0, 'Eastern Europe'),
#  Text(4, 0, 'North America'),
#  Text(5, 0, 'East Asia'),
#  Text(6, 0, 'Northern Europe'),
#  Text(7, 0, 'South Asia'),
#  Text(8, 0, 'Middle East'),
#  Text(9, 0, 'Southeast Asia')]

# %%
chart = sns.boxplot(x='Region',y='gasPrice2016', data=df, sym='')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Africa'),
#  Text(1, 0, 'Western Europe'),
#  Text(2, 0, 'Western Asia'),
#  Text(3, 0, 'Eastern Europe'),
#  Text(4, 0, 'North America'),
#  Text(5, 0, 'East Asia'),
#  Text(6, 0, 'Northern Europe'),
#  Text(7, 0, 'South Asia'),
#  Text(8, 0, 'Middle East'),
#  Text(9, 0, 'Southeast Asia')]

# %%
#not work
Q1 = df['gasPrice2012'].quantile(0.25)
Q3 = df['gasPrice2012'].quantile(0.75)
IQR = Q3 - Q1    #IQR is interquartile range. 

filter = (df['gasPrice2012'] >= Q1 - 1.5 * IQR) & (df['gasPrice2012'] <= Q3 + 1.5 *IQR)
df2 = df.loc[filter]

# %%
# not work
chart = sns.boxplot(x='Region',y='gasPrice2012', data=df2)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Africa'),
#  Text(1, 0, 'Western Europe'),
#  Text(2, 0, 'Western Asia'),
#  Text(3, 0, 'Eastern Europe'),
#  Text(4, 0, 'North America'),
#  Text(5, 0, 'East Asia'),
#  Text(6, 0, 'Northern Europe'),
#  Text(7, 0, 'South Asia'),
#  Text(8, 0, 'Middle East'),
#  Text(9, 0, 'Southeast Asia')]

# %%
sns.violinplot(x='Region',y='airtrans2016',data=df, hue='ThirdWorld')
# Out:
# <AxesSubplot:xlabel='Region', ylabel='airtrans2016'>

# %%
chart = sns.boxplot(x='Region',y='airtrans2016', data=df, hue='ThirdWorld')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Africa'),
#  Text(1, 0, 'Western Europe'),
#  Text(2, 0, 'Western Asia'),
#  Text(3, 0, 'Eastern Europe'),
#  Text(4, 0, 'North America'),
#  Text(5, 0, 'East Asia'),
#  Text(6, 0, 'Northern Europe'),
#  Text(7, 0, 'South Asia'),
#  Text(8, 0, 'Middle East'),
#  Text(9, 0, 'Southeast Asia')]

# %%
sns.heatmap(df.corr(),
            square=True,
            linewidths=0.25,    
            linecolor=(0,0,0),
           cmap=sns.color_palette("coolwarm"),
           annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='ThirdWorld', markers=["o", "D"],diag_kws={'bw': 0.2})
#diag_kws={'bw': 0.2}
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.2 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.2 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.pairplot(df, vars = ['airtrans2016', 'railLines2016'], hue='ThirdWorld', markers=["o", "D"])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
chart = sns.relplot(data=df,
                    x="airtrans2016", 
                    y="railLines2016", 
                    hue="ThirdWorld", 
                    size="railLines2012",
                    sizes=(40, 400), 
                    alpha=.5, 
                    palette=sns.color_palette("muted",len(df['ThirdWorld'].unique())),
                    height=6)

# %%
sns.jointplot(data=df,
               x="airtrans2016", 
               y="railLines2016",
               color=(102/255,205/255,170/255))  # rgb
