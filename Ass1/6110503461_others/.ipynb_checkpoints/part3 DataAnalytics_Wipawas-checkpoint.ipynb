# %%
import os
os.chdir('C:\\Users\\User\\Documents\\stat2020\\Week2_data\\transportation')
os.getcwd()
# Out:
# 'C:\\Users\\User\\Documents\\stat2020\\Week2_data\\transportation'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('airTrans_gdp_etertia_2012_2016.csv',sep=',', header='infer')
df.head()
# Out:
#       CountryName                 Region  ThirdWorld  airTrans2012  \
# 0     Afghanistan             South Asia           1  17775.000000
# 1         Albania         Eastern Europe           0  10309.179138
# 2         Algeria                 Africa           0  54292.000000
# 3  American Samoa  Australia and Oceanea           0   3963.003648
# 4         Andorra         Western Europe           0           NaN
#
#    airTrans2016       gdp2012       gdp2016  enrollTertiary2012  \
# 0       22770.0    641.872034    547.228110                 NaN
# 1         306.0   4247.614342   4124.108543            59.25201
# 2       73465.0   5592.221910   3948.811897            32.20153
# 3           NaN  11568.793001  11714.895678                 NaN
# 4           NaN  38392.943901  37224.108916                 NaN
#
#    enrollTertiary2016
# 0                 NaN
# 1            58.38185
# 2            42.62885
# 3                 NaN
# 4                 NaN

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df.dropna()
# Out:
#         CountryName           Region  ThirdWorld  airTrans2012  airTrans2016  \
# 1           Albania   Eastern Europe           0  1.030918e+04         306.0
# 2           Algeria           Africa           0  5.429200e+04       73465.0
# 7         Argentina    South America           0  1.017163e+05      149334.0
# 11          Austria   Western Europe           0  1.627157e+05      149030.0
# 12       Azerbaijan     Western Asia           0  1.659700e+04       24009.0
# ..              ...              ...         ...           ...           ...
# 197         Tunisia           Africa           0  3.723300e+04       38631.0
# 205  United Kingdom  Northern Europe           0  1.050703e+06     1180312.0
# 206   United States    North America           0  9.864360e+06     9640591.0
# 208      Uzbekistan     Western Asia           0  2.432800e+04       21486.0
# 211         Vietnam   Southeast Asia           0  1.353004e+05      248580.0
#
# ...

# %%
df2 = df.drop(['ThirdWorld'], axis=1)

# %%
sns.heatmap(df2.corr(),
            square=True,
            linewidths=0.25,    
            linecolor=(0,0,0),
           cmap=sns.color_palette("coolwarm"),
           annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df2)

# %%
sns.pairplot(df2, markers=["o", "D"])
#diag_kws={'bw': 0.2}

# %%
sns.pairplot(df2, vars = ['airTrans2012', 'enrollTertiary2012'], markers=["o", "D"])

# %%
sns.lmplot(x='airTrans2012', y='enrollTertiary2012', fit_reg=False, data=df2, hue='Region');

# %%
import matplotlib.pyplot as plt
plt.scatter(df2['airTrans2012'],df2['enrollTertiary2012'])
plt.show()
