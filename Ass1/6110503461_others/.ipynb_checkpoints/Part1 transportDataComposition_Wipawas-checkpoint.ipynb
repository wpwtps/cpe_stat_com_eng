# %%
import os
os.chdir('C:\\Users\\User\\Documents\\stat2020\\Week2_data\\transportation')
os.getcwd()
# Out:
# 'C:\\Users\\User\\Documents\\stat2020\\Week2_data\\transportation'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
regions = pd.read_excel('countries_regions.xlsx')
regions.head()
# Out:
#       CountryName                 Region  ThirdWorld
# 0     Afghanistan             South Asia           1
# 1         Albania         Eastern Europe           0
# 2         Algeria                 Africa           0
# 3  American Samoa  Australia and Oceanea           0
# 4         Andorra         Western Europe           0

# %% [markdown]
# # 1st File: Railline

# %%
df = pd.read_excel('railLines_totalroutePerKm.xlsx',sheet_name='Data')
df
# Out:
#                                           Series Name     Series Code  \
# 0                         Rail lines (total route-km)  IS.RRS.TOTL.KM
# 1                         Rail lines (total route-km)  IS.RRS.TOTL.KM
# 2                         Rail lines (total route-km)  IS.RRS.TOTL.KM
# 3                         Rail lines (total route-km)  IS.RRS.TOTL.KM
# 4                         Rail lines (total route-km)  IS.RRS.TOTL.KM
# ..                                                ...             ...
# 217                                               NaN             NaN
# 218                                               NaN             NaN
# 219                                               NaN             NaN
# 220  Data from database: World Development Indicators             NaN
# 221                          Last Updated: 10/28/2019             NaN
#
#        Country Name Country Code 1990 [YR1990] 2000 [YR2000] 2010 [YR2010]  \
# ...

# %%
df2 = df
df2.drop([217,218,219,220,221], inplace=True)

# %%
df2.replace({'..':np.nan}, inplace=True)
df
# Out:
#                      Series Name     Series Code           Country Name  \
# 0    Rail lines (total route-km)  IS.RRS.TOTL.KM            Afghanistan
# 1    Rail lines (total route-km)  IS.RRS.TOTL.KM                Albania
# 2    Rail lines (total route-km)  IS.RRS.TOTL.KM                Algeria
# 3    Rail lines (total route-km)  IS.RRS.TOTL.KM         American Samoa
# 4    Rail lines (total route-km)  IS.RRS.TOTL.KM                Andorra
# ..                           ...             ...                    ...
# 212  Rail lines (total route-km)  IS.RRS.TOTL.KM  Virgin Islands (U.S.)
# 213  Rail lines (total route-km)  IS.RRS.TOTL.KM     West Bank and Gaza
# 214  Rail lines (total route-km)  IS.RRS.TOTL.KM            Yemen, Rep.
# 215  Rail lines (total route-km)  IS.RRS.TOTL.KM                 Zambia
# 216  Rail lines (total route-km)  IS.RRS.TOTL.KM               Zimbabwe
#
#     Country Code  1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  2011 [YR2011]  \
# ...

# %%
sns.heatmap(df2.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df2 = df
df2.drop([216,215,214,213,212], inplace=True)

# %%
df
# Out:
#                      Series Name     Series Code    Country Name Country Code  \
# 0    Rail lines (total route-km)  IS.RRS.TOTL.KM     Afghanistan          AFG
# 1    Rail lines (total route-km)  IS.RRS.TOTL.KM         Albania          ALB
# 2    Rail lines (total route-km)  IS.RRS.TOTL.KM         Algeria          DZA
# 3    Rail lines (total route-km)  IS.RRS.TOTL.KM  American Samoa          ASM
# 4    Rail lines (total route-km)  IS.RRS.TOTL.KM         Andorra          AND
# ..                           ...             ...             ...          ...
# 207  Rail lines (total route-km)  IS.RRS.TOTL.KM         Uruguay          URY
# 208  Rail lines (total route-km)  IS.RRS.TOTL.KM      Uzbekistan          UZB
# 209  Rail lines (total route-km)  IS.RRS.TOTL.KM         Vanuatu          VUT
# 210  Rail lines (total route-km)  IS.RRS.TOTL.KM   Venezuela, RB          VEN
# 211  Rail lines (total route-km)  IS.RRS.TOTL.KM         Vietnam          VNM
#
# ...

# %%
sns.heatmap(df2.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df2.drop(['2018 [YR2018]','2019 [YR2019]'],axis=1, inplace=True)
df2.head()
# Out:
#                    Series Name     Series Code    Country Name Country Code  \
# 0  Rail lines (total route-km)  IS.RRS.TOTL.KM     Afghanistan          AFG
# 1  Rail lines (total route-km)  IS.RRS.TOTL.KM         Albania          ALB
# 2  Rail lines (total route-km)  IS.RRS.TOTL.KM         Algeria          DZA
# 3  Rail lines (total route-km)  IS.RRS.TOTL.KM  American Samoa          ASM
# 4  Rail lines (total route-km)  IS.RRS.TOTL.KM         Andorra          AND
#
#    1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN          440.0            NaN            NaN            NaN
# 2            NaN         3973.0         3664.0         4226.0         4175.0
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
# ...

# %%
sns.heatmap(df2.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df2.drop(['1990 [YR1990]'],axis=1, inplace=True)
df2.head()
# Out:
#                    Series Name     Series Code    Country Name Country Code  \
# 0  Rail lines (total route-km)  IS.RRS.TOTL.KM     Afghanistan          AFG
# 1  Rail lines (total route-km)  IS.RRS.TOTL.KM         Albania          ALB
# 2  Rail lines (total route-km)  IS.RRS.TOTL.KM         Algeria          DZA
# 3  Rail lines (total route-km)  IS.RRS.TOTL.KM  American Samoa          ASM
# 4  Rail lines (total route-km)  IS.RRS.TOTL.KM         Andorra          AND
#
#    2000 [YR2000]  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1          440.0            NaN            NaN            NaN            NaN
# 2         3973.0         3664.0         4226.0         4175.0            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
# ...

# %%
sns.heatmap(df2.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 2nd File: airtransport

# %%
df3 = pd.read_excel('airtransport.xlsx',sheet_name='Data')
df3.head()
# Out:
#                                          Series Name  Series Code  \
# 0  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 1  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 2  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 3  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 4  Air transport, registered carrier departures w...  IS.AIR.DPRT
#
#      Country Name Country Code 1990 [YR1990] 2000 [YR2000] 2010 [YR2010]  \
# 0     Afghanistan          AFG          5300          3409         21677
# 1         Albania          ALB            ..          3885          9412
# 2         Algeria          DZA         44100         40202         53088
# 3  American Samoa          ASM            ..            ..       3420.57
# 4         Andorra          AND            ..            ..            ..
#
#   2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015]  \
# ...

# %%
df3.tail(10)
# Out:
#                                            Series Name  Series Code  \
# 212  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 213  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 214  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 215  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 216  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 217                                                NaN          NaN
# 218                                                NaN          NaN
# 219                                                NaN          NaN
# 220   Data from database: World Development Indicators          NaN
# 221                           Last Updated: 10/28/2019          NaN
#
#               Country Name Country Code 1990 [YR1990] 2000 [YR2000]  \
# 212  Virgin Islands (U.S.)          VIR            ..            ..
# 213     West Bank and Gaza          PSE            ..            ..
# ...

# %%
df3.drop([217, 218, 219, 220, 221], inplace=True)

# %%
df3.replace({'..':np.nan}, inplace=True)
df3.head()
# Out:
#                                          Series Name  Series Code  \
# 0  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 1  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 2  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 3  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 4  Air transport, registered carrier departures w...  IS.AIR.DPRT
#
#      Country Name Country Code  1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  \
# 0     Afghanistan          AFG         5300.0         3409.0   21677.000000
# 1         Albania          ALB            NaN         3885.0    9412.000000
# 2         Algeria          DZA        44100.0        40202.0   53088.000000
# 3  American Samoa          ASM            NaN            NaN    3420.570755
# 4         Andorra          AND            NaN            NaN            NaN
#
#    2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  \
# ...

# %%
sns.heatmap(df3.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df3.drop(['2019 [YR2019]'],axis=1, inplace=True)
df3.head()
# Out:
#                                          Series Name  Series Code  \
# 0  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 1  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 2  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 3  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 4  Air transport, registered carrier departures w...  IS.AIR.DPRT
#
#      Country Name Country Code  1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  \
# 0     Afghanistan          AFG         5300.0         3409.0   21677.000000
# 1         Albania          ALB            NaN         3885.0    9412.000000
# 2         Algeria          DZA        44100.0        40202.0   53088.000000
# 3  American Samoa          ASM            NaN            NaN    3420.570755
# 4         Andorra          AND            NaN            NaN            NaN
#
#    2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  \
# ...

# %%
sns.heatmap(df3.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df5 = regions.join(df3[['2012 [YR2012]','2016 [YR2016]']])
df5
# Out:
#                CountryName                 Region  ThirdWorld  2012 [YR2012]  \
# 0              Afghanistan             South Asia           1   17775.000000
# 1                  Albania         Eastern Europe           0   10309.179138
# 2                  Algeria                 Africa           0   54292.000000
# 3           American Samoa  Australia and Oceanea           0    3963.003648
# 4                  Andorra         Western Europe           0            NaN
# ..                     ...                    ...         ...            ...
# 212  Virgin Islands (U.S.)          North America           0            NaN
# 213     West Bank and Gaza            Middle East           0            NaN
# 214            Yemen, Rep.            Middle East           1   16807.407296
# 215                 Zambia                 Africa           1    8288.000000
# 216               Zimbabwe                 Africa           0   11560.367854
#
#      2016 [YR2016]
# 0          22770.0
# ...

# %%
df5.rename(columns={'2012 [YR2012]':'Past2012','2016 [YR2016]':'Present2016'}, inplace=True)
#df5.head()
df5.rename(columns={'Past2012':'airtrans2012','Present2016':'airtrans2016'}, inplace=True)
df5.head()
# Out:
#       CountryName                 Region  ThirdWorld  airtrans2012  \
# 0     Afghanistan             South Asia           1  17775.000000
# 1         Albania         Eastern Europe           0  10309.179138
# 2         Algeria                 Africa           0  54292.000000
# 3  American Samoa  Australia and Oceanea           0   3963.003648
# 4         Andorra         Western Europe           0           NaN
#
#    airtrans2016
# 0       22770.0
# 1         306.0
# 2       73465.0
# 3           NaN
# 4           NaN

# %%
df5 = df5.join(df2[['2012 [YR2012]','2016 [YR2016]']])
df5
# Out:
#                CountryName                 Region  ThirdWorld  airtrans2012  \
# 0              Afghanistan             South Asia           1  17775.000000
# 1                  Albania         Eastern Europe           0  10309.179138
# 2                  Algeria                 Africa           0  54292.000000
# 3           American Samoa  Australia and Oceanea           0   3963.003648
# 4                  Andorra         Western Europe           0           NaN
# ..                     ...                    ...         ...           ...
# 212  Virgin Islands (U.S.)          North America           0           NaN
# 213     West Bank and Gaza            Middle East           0           NaN
# 214            Yemen, Rep.            Middle East           1  16807.407296
# 215                 Zambia                 Africa           1   8288.000000
# 216               Zimbabwe                 Africa           0  11560.367854
#
#      airtrans2016  2012 [YR2012]  2016 [YR2016]
# ...

# %%
df5.rename(columns={'2012 [YR2012]':'railLines2012','2016 [YR2016]':'railLines2016'}, inplace=True)
df5.head()
# Out:
#       CountryName                 Region  ThirdWorld  airtrans2012  \
# 0     Afghanistan             South Asia           1  17775.000000
# 1         Albania         Eastern Europe           0  10309.179138
# 2         Algeria                 Africa           0  54292.000000
# 3  American Samoa  Australia and Oceanea           0   3963.003648
# 4         Andorra         Western Europe           0           NaN
#
#    airtrans2016  railLines2012  railLines2016
# 0       22770.0            NaN            NaN
# 1         306.0            NaN            NaN
# 2       73465.0         4175.0        3843.17
# 3           NaN            NaN            NaN
# 4           NaN            NaN            NaN

# %% [markdown]
# # 3rd File: gas_price

# %%
df6 = pd.read_excel('gas_price.xlsx',sheet_name='Data')
df6
# Out:
#                                           Series Name     Series Code  \
# 0          Pump price for diesel fuel (US$ per liter)  EP.PMP.DESL.CD
# 1          Pump price for diesel fuel (US$ per liter)  EP.PMP.DESL.CD
# 2          Pump price for diesel fuel (US$ per liter)  EP.PMP.DESL.CD
# 3          Pump price for diesel fuel (US$ per liter)  EP.PMP.DESL.CD
# 4          Pump price for diesel fuel (US$ per liter)  EP.PMP.DESL.CD
# ..                                                ...             ...
# 217                                               NaN             NaN
# 218                                               NaN             NaN
# 219                                               NaN             NaN
# 220  Data from database: World Development Indicators             NaN
# 221                          Last Updated: 10/28/2019             NaN
#
#        Country Name Country Code 1990 [YR1990] 2000 [YR2000] 2010 [YR2010]  \
# ...

# %%
df6.drop([217,218,219,220,221], inplace=True)
df6.replace({'..':np.nan}, inplace=True)
df6
# Out:
#                                     Series Name     Series Code  \
# 0    Pump price for diesel fuel (US$ per liter)  EP.PMP.DESL.CD
# 1    Pump price for diesel fuel (US$ per liter)  EP.PMP.DESL.CD
# 2    Pump price for diesel fuel (US$ per liter)  EP.PMP.DESL.CD
# 3    Pump price for diesel fuel (US$ per liter)  EP.PMP.DESL.CD
# 4    Pump price for diesel fuel (US$ per liter)  EP.PMP.DESL.CD
# ..                                          ...             ...
# 212  Pump price for diesel fuel (US$ per liter)  EP.PMP.DESL.CD
# 213  Pump price for diesel fuel (US$ per liter)  EP.PMP.DESL.CD
# 214  Pump price for diesel fuel (US$ per liter)  EP.PMP.DESL.CD
# 215  Pump price for diesel fuel (US$ per liter)  EP.PMP.DESL.CD
# 216  Pump price for diesel fuel (US$ per liter)  EP.PMP.DESL.CD
#
#               Country Name Country Code  1990 [YR1990]  2000 [YR2000]  \
# 0              Afghanistan          AFG            NaN            NaN
# ...

# %%
sns.heatmap(df6.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df6.drop(['1990 [YR1990]','2017 [YR2017]','2018 [YR2018]','2019 [YR2019]'],axis=1, inplace=True)
df6.head()
# Out:
#                                   Series Name     Series Code    Country Name  \
# 0  Pump price for diesel fuel (US$ per liter)  EP.PMP.DESL.CD     Afghanistan
# 1  Pump price for diesel fuel (US$ per liter)  EP.PMP.DESL.CD         Albania
# 2  Pump price for diesel fuel (US$ per liter)  EP.PMP.DESL.CD         Algeria
# 3  Pump price for diesel fuel (US$ per liter)  EP.PMP.DESL.CD  American Samoa
# 4  Pump price for diesel fuel (US$ per liter)  EP.PMP.DESL.CD         Andorra
#
#   Country Code  2000 [YR2000]  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  \
# 0          AFG            NaN           1.00            NaN           1.21
# 1          ALB           0.30           1.40            NaN           1.79
# 2          DZA           0.15           0.19            NaN           0.17
# 3          ASM            NaN            NaN            NaN            NaN
# 4          AND            NaN           1.32            NaN           1.48
#
# ...

# %%
sns.heatmap(df6.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df7 = regions.join(df6[['2012 [YR2012]', '2016 [YR2016]']])
df7
# Out:
#                CountryName                 Region  ThirdWorld  2012 [YR2012]  \
# 0              Afghanistan             South Asia           1           1.21
# 1                  Albania         Eastern Europe           0           1.79
# 2                  Algeria                 Africa           0           0.17
# 3           American Samoa  Australia and Oceanea           0            NaN
# 4                  Andorra         Western Europe           0           1.48
# ..                     ...                    ...         ...            ...
# 212  Virgin Islands (U.S.)          North America           0            NaN
# 213     West Bank and Gaza            Middle East           0           1.68
# 214            Yemen, Rep.            Middle East           1           0.47
# 215                 Zambia                 Africa           1           1.48
# 216               Zimbabwe                 Africa           0           1.40
#
#      2016 [YR2016]
# 0             0.70
# ...

# %%
df5
# Out:
#                CountryName                 Region  ThirdWorld  airtrans2012  \
# 0              Afghanistan             South Asia           1  17775.000000
# 1                  Albania         Eastern Europe           0  10309.179138
# 2                  Algeria                 Africa           0  54292.000000
# 3           American Samoa  Australia and Oceanea           0   3963.003648
# 4                  Andorra         Western Europe           0           NaN
# ..                     ...                    ...         ...           ...
# 212  Virgin Islands (U.S.)          North America           0           NaN
# 213     West Bank and Gaza            Middle East           0           NaN
# 214            Yemen, Rep.            Middle East           1  16807.407296
# 215                 Zambia                 Africa           1   8288.000000
# 216               Zimbabwe                 Africa           0  11560.367854
#
#      airtrans2016  railLines2012  railLines2016
# ...

# %%
df5 = df5.join(df6[['2012 [YR2012]','2016 [YR2016]']])
df5
# Out:
#                CountryName                 Region  ThirdWorld  airtrans2012  \
# 0              Afghanistan             South Asia           1  17775.000000
# 1                  Albania         Eastern Europe           0  10309.179138
# 2                  Algeria                 Africa           0  54292.000000
# 3           American Samoa  Australia and Oceanea           0   3963.003648
# 4                  Andorra         Western Europe           0           NaN
# ..                     ...                    ...         ...           ...
# 212  Virgin Islands (U.S.)          North America           0           NaN
# 213     West Bank and Gaza            Middle East           0           NaN
# 214            Yemen, Rep.            Middle East           1  16807.407296
# 215                 Zambia                 Africa           1   8288.000000
# 216               Zimbabwe                 Africa           0  11560.367854
#
# ...

# %%
df5.rename(columns={'2012 [YR2012]':'gasPrice2012','2016 [YR2016]':'gasPrice2016'}, inplace=True)
df5.head()
# Out:
#       CountryName                 Region  ThirdWorld  airtrans2012  \
# 0     Afghanistan             South Asia           1  17775.000000
# 1         Albania         Eastern Europe           0  10309.179138
# 2         Algeria                 Africa           0  54292.000000
# 3  American Samoa  Australia and Oceanea           0   3963.003648
# 4         Andorra         Western Europe           0           NaN
#
#    airtrans2016  railLines2012  railLines2016  gasPrice2012  gasPrice2016
# 0       22770.0            NaN            NaN          1.21          0.70
# 1         306.0            NaN            NaN          1.79          1.35
# 2       73465.0         4175.0        3843.17          0.17          0.17
# 3           NaN            NaN            NaN           NaN           NaN
# 4           NaN            NaN            NaN          1.48           NaN

# %%
sns.heatmap(df5.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df8 = df5.dropna()
df8.head()
# Out:
#    CountryName          Region  ThirdWorld   airtrans2012  airtrans2016  \
# 2      Algeria          Africa           0   54292.000000       73465.0
# 11     Austria  Western Europe           0  162715.735981      149030.0
# 12  Azerbaijan    Western Asia           0   16597.000000       24009.0
# 17     Belarus  Eastern Europe           0   14608.000000       26857.0
# 18     Belgium  Western Europe           0  132099.342542      147324.0
#
#     railLines2012  railLines2016  gasPrice2012  gasPrice2016
# 2          4175.0        3843.17          0.17          0.17
# 11         4985.0        4917.00          1.81          1.15
# 12         2068.1        2074.00          0.57          0.35
# 17         5462.0        5459.00          0.90          0.62
# 18         3592.0        3602.00          1.98          1.32

# %%
sns.heatmap(df8.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df8.shape
# Out:
# (51, 9)

# %%
df8.to_csv('air_rail_gas_2012_2016.csv',index=False)
