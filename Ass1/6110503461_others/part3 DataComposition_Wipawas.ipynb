# %%
import os
os.chdir('C:\\Users\\User\\Documents\\stat2020\\Week2_data\\transportation')
os.getcwd()
# Out:
# 'C:\\Users\\User\\Documents\\stat2020\\Week2_data\\transportation'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
air = pd.read_excel('airtransport.xlsx')
air.head()
# Out:
#                                          Series Name  Series Code  \
# 0  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 1  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 2  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 3  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 4  Air transport, registered carrier departures w...  IS.AIR.DPRT
#
#      Country Name Country Code 1990 [YR1990] 2000 [YR2000] 2010 [YR2010]  \
# 0     Afghanistan          AFG          5300          3409         21677
# 1         Albania          ALB            ..          3885          9412
# 2         Algeria          DZA         44100         40202         53088
# 3  American Samoa          ASM            ..            ..       3420.57
# 4         Andorra          AND            ..            ..            ..
#
#   2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015]  \
# ...

# %%
gdp = pd.read_excel('gdp_per_capita.xlsx')
gdp.head()
# Out:
#                     Series Name     Series Code    Country Name Country Code  \
# 0  GDP per capita (current US$)  NY.GDP.PCAP.CD     Afghanistan          AFG
# 1  GDP per capita (current US$)  NY.GDP.PCAP.CD         Albania          ALB
# 2  GDP per capita (current US$)  NY.GDP.PCAP.CD         Algeria          DZA
# 3  GDP per capita (current US$)  NY.GDP.PCAP.CD  American Samoa          ASM
# 4  GDP per capita (current US$)  NY.GDP.PCAP.CD         Andorra          AND
#
#   1990 [YR1990] 2000 [YR2000] 2010 [YR2010] 2011 [YR2011] 2012 [YR2012]  \
# 0            ..            ..       543.303       591.162       641.872
# 1        617.23       1126.68       4094.36       4437.18       4247.61
# 2       2408.69       1765.02       4480.79       5455.84       5592.22
# 3            ..            ..       10271.2       10294.3       11568.8
# 4       18878.5       21936.5       39736.4       41100.7       38392.9
#
# ...

# %%
regions = pd.read_excel('countries_regions.xlsx')
regions.head()
# Out:
#       CountryName                 Region  ThirdWorld
# 0     Afghanistan             South Asia           1
# 1         Albania         Eastern Europe           0
# 2         Algeria                 Africa           0
# 3  American Samoa  Australia and Oceanea           0
# 4         Andorra         Western Europe           0

# %%
air
# Out:
#                                            Series Name  Series Code  \
# 0    Air transport, registered carrier departures w...  IS.AIR.DPRT
# 1    Air transport, registered carrier departures w...  IS.AIR.DPRT
# 2    Air transport, registered carrier departures w...  IS.AIR.DPRT
# 3    Air transport, registered carrier departures w...  IS.AIR.DPRT
# 4    Air transport, registered carrier departures w...  IS.AIR.DPRT
# ..                                                 ...          ...
# 217                                                NaN          NaN
# 218                                                NaN          NaN
# 219                                                NaN          NaN
# 220   Data from database: World Development Indicators          NaN
# 221                           Last Updated: 10/28/2019          NaN
#
#        Country Name Country Code 1990 [YR1990] 2000 [YR2000] 2010 [YR2010]  \
# ...

# %%
air2 = air
air2.drop([217,218,219,220,221], inplace=True)

# %%
air2.replace({'..':np.nan}, inplace=True)
air
# Out:
#                                            Series Name  Series Code  \
# 0    Air transport, registered carrier departures w...  IS.AIR.DPRT
# 1    Air transport, registered carrier departures w...  IS.AIR.DPRT
# 2    Air transport, registered carrier departures w...  IS.AIR.DPRT
# 3    Air transport, registered carrier departures w...  IS.AIR.DPRT
# 4    Air transport, registered carrier departures w...  IS.AIR.DPRT
# ..                                                 ...          ...
# 212  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 213  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 214  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 215  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 216  Air transport, registered carrier departures w...  IS.AIR.DPRT
#
#               Country Name Country Code  1990 [YR1990]  2000 [YR2000]  \
# 0              Afghanistan          AFG         5300.0         3409.0
# ...

# %%
gdp
# Out:
#                                           Series Name     Series Code  \
# 0                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 1                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 2                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 3                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 4                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# ..                                                ...             ...
# 217                                               NaN             NaN
# 218                                               NaN             NaN
# 219                                               NaN             NaN
# 220  Data from database: World Development Indicators             NaN
# 221                          Last Updated: 10/28/2019             NaN
#
#        Country Name Country Code 1990 [YR1990] 2000 [YR2000] 2010 [YR2010]  \
# ...

# %%
gdp2 = gdp
gdp2.drop([217,218,219,220,221], inplace=True)
gdp2.replace({'..':np.nan}, inplace=True)
gdp2
# Out:
#                       Series Name     Series Code           Country Name  \
# 0    GDP per capita (current US$)  NY.GDP.PCAP.CD            Afghanistan
# 1    GDP per capita (current US$)  NY.GDP.PCAP.CD                Albania
# 2    GDP per capita (current US$)  NY.GDP.PCAP.CD                Algeria
# 3    GDP per capita (current US$)  NY.GDP.PCAP.CD         American Samoa
# 4    GDP per capita (current US$)  NY.GDP.PCAP.CD                Andorra
# ..                            ...             ...                    ...
# 212  GDP per capita (current US$)  NY.GDP.PCAP.CD  Virgin Islands (U.S.)
# 213  GDP per capita (current US$)  NY.GDP.PCAP.CD     West Bank and Gaza
# 214  GDP per capita (current US$)  NY.GDP.PCAP.CD            Yemen, Rep.
# 215  GDP per capita (current US$)  NY.GDP.PCAP.CD                 Zambia
# 216  GDP per capita (current US$)  NY.GDP.PCAP.CD               Zimbabwe
#
#     Country Code  1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  2011 [YR2011]  \
# ...

# %%
regions
# Out:
#                CountryName                 Region  ThirdWorld
# 0              Afghanistan             South Asia           1
# 1                  Albania         Eastern Europe           0
# 2                  Algeria                 Africa           0
# 3           American Samoa  Australia and Oceanea           0
# 4                  Andorra         Western Europe           0
# ..                     ...                    ...         ...
# 212  Virgin Islands (U.S.)          North America           0
# 213     West Bank and Gaza            Middle East           0
# 214            Yemen, Rep.            Middle East           1
# 215                 Zambia                 Africa           1
# 216               Zimbabwe                 Africa           0
#
# [217 rows x 3 columns]

# %%
df = regions.join(air2[['2012 [YR2012]','2016 [YR2016]']])
df.rename(columns={'2012 [YR2012]':'airTrans2012','2016 [YR2016]':'airTrans2016'}, inplace=True)
#df5.head()
df
# Out:
#                CountryName                 Region  ThirdWorld  airTrans2012  \
# 0              Afghanistan             South Asia           1  17775.000000
# 1                  Albania         Eastern Europe           0  10309.179138
# 2                  Algeria                 Africa           0  54292.000000
# 3           American Samoa  Australia and Oceanea           0   3963.003648
# 4                  Andorra         Western Europe           0           NaN
# ..                     ...                    ...         ...           ...
# 212  Virgin Islands (U.S.)          North America           0           NaN
# 213     West Bank and Gaza            Middle East           0           NaN
# 214            Yemen, Rep.            Middle East           1  16807.407296
# 215                 Zambia                 Africa           1   8288.000000
# 216               Zimbabwe                 Africa           0  11560.367854
#
#      airTrans2016
# 0         22770.0
# ...

# %%
df2 = df.join(gdp2[['2012 [YR2012]','2016 [YR2016]']])
df2.rename(columns={'2012 [YR2012]':'gdp2012','2016 [YR2016]':'gdp2016'}, inplace=True)
#df5.head()
df2
# Out:
#                CountryName                 Region  ThirdWorld  airTrans2012  \
# 0              Afghanistan             South Asia           1  17775.000000
# 1                  Albania         Eastern Europe           0  10309.179138
# 2                  Algeria                 Africa           0  54292.000000
# 3           American Samoa  Australia and Oceanea           0   3963.003648
# 4                  Andorra         Western Europe           0           NaN
# ..                     ...                    ...         ...           ...
# 212  Virgin Islands (U.S.)          North America           0           NaN
# 213     West Bank and Gaza            Middle East           0           NaN
# 214            Yemen, Rep.            Middle East           1  16807.407296
# 215                 Zambia                 Africa           1   8288.000000
# 216               Zimbabwe                 Africa           0  11560.367854
#
#      airTrans2016       gdp2012       gdp2016
# ...

# %%
enroll = pd.read_excel('schoolEnroll_tertiary_grossPercent.xlsx')
enroll.head()
# Out:
#                              Series Name  Series Code    Country Name  \
# 0  School enrollment, tertiary (% gross)  SE.TER.ENRR     Afghanistan
# 1  School enrollment, tertiary (% gross)  SE.TER.ENRR         Albania
# 2  School enrollment, tertiary (% gross)  SE.TER.ENRR         Algeria
# 3  School enrollment, tertiary (% gross)  SE.TER.ENRR  American Samoa
# 4  School enrollment, tertiary (% gross)  SE.TER.ENRR         Andorra
#
#   Country Code 1990 [YR1990] 2000 [YR2000] 2010 [YR2010] 2011 [YR2011]  \
# 0          AFG       2.21141            ..            ..       3.62226
# 1          ALB       8.36636       15.5366       44.5493       49.8787
# 2          DZA       10.2931            ..       29.8894       31.2141
# 3          ASM            ..            ..            ..            ..
# 4          AND            ..            ..            ..            ..
#
#   2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015] 2016 [YR2016]  \
# ...

# %%
enroll2 = enroll
enroll2.drop([217,218,219,220,221], inplace=True)
enroll2.replace({'..':np.nan}, inplace=True)
enroll2
# Out:
#                                Series Name  Series Code  \
# 0    School enrollment, tertiary (% gross)  SE.TER.ENRR
# 1    School enrollment, tertiary (% gross)  SE.TER.ENRR
# 2    School enrollment, tertiary (% gross)  SE.TER.ENRR
# 3    School enrollment, tertiary (% gross)  SE.TER.ENRR
# 4    School enrollment, tertiary (% gross)  SE.TER.ENRR
# ..                                     ...          ...
# 212  School enrollment, tertiary (% gross)  SE.TER.ENRR
# 213  School enrollment, tertiary (% gross)  SE.TER.ENRR
# 214  School enrollment, tertiary (% gross)  SE.TER.ENRR
# 215  School enrollment, tertiary (% gross)  SE.TER.ENRR
# 216  School enrollment, tertiary (% gross)  SE.TER.ENRR
#
#               Country Name Country Code  1990 [YR1990]  2000 [YR2000]  \
# 0              Afghanistan          AFG        2.21141            NaN
# 1                  Albania          ALB        8.36636       15.53661
# 2                  Algeria          DZA       10.29314            NaN
# ...

# %%
df3 = df2.join(enroll2[['2012 [YR2012]','2016 [YR2016]']])
df3.rename(columns={'2012 [YR2012]':'enrollTertiary2012','2016 [YR2016]':'enrollTertiary2016'}, inplace=True)
#df5.head()
df3
# Out:
#                CountryName                 Region  ThirdWorld  airTrans2012  \
# 0              Afghanistan             South Asia           1  17775.000000
# 1                  Albania         Eastern Europe           0  10309.179138
# 2                  Algeria                 Africa           0  54292.000000
# 3           American Samoa  Australia and Oceanea           0   3963.003648
# 4                  Andorra         Western Europe           0           NaN
# ..                     ...                    ...         ...           ...
# 212  Virgin Islands (U.S.)          North America           0           NaN
# 213     West Bank and Gaza            Middle East           0           NaN
# 214            Yemen, Rep.            Middle East           1  16807.407296
# 215                 Zambia                 Africa           1   8288.000000
# 216               Zimbabwe                 Africa           0  11560.367854
#
# ...

# %%
df3.to_csv('airTrans_gdp_etertia_2012_2016.csv',index=False)
