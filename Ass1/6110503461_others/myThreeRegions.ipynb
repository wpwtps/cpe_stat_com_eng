# %%
import os
os.chdir('C:\\Users\\User\\Documents\\stat2020\\Week2_data\\transportation')
os.getcwd()
# Out:
# 'C:\\Users\\User\\Documents\\stat2020\\Week2_data\\transportation'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
regions = pd.read_excel('countries_regions.xlsx')
regions.head()
# Out:
#       CountryName                 Region  ThirdWorld
# 0     Afghanistan             South Asia           1
# 1         Albania         Eastern Europe           0
# 2         Algeria                 Africa           0
# 3  American Samoa  Australia and Oceanea           0
# 4         Andorra         Western Europe           0

# %%
df = pd.read_excel('countries_regions.xlsx',sheet_name='Sheet1')
df
# Out:
#                CountryName                 Region  ThirdWorld
# 0              Afghanistan             South Asia           1
# 1                  Albania         Eastern Europe           0
# 2                  Algeria                 Africa           0
# 3           American Samoa  Australia and Oceanea           0
# 4                  Andorra         Western Europe           0
# ..                     ...                    ...         ...
# 212  Virgin Islands (U.S.)          North America           0
# 213     West Bank and Gaza            Middle East           0
# 214            Yemen, Rep.            Middle East           1
# 215                 Zambia                 Africa           1
# 216               Zimbabwe                 Africa           0
#
# [217 rows x 3 columns]

# %%
df2 = df

# %%
def label_EastAsia (row):
    if row['Region'] == 'East Asia':
        return '1'
    return '0'

def label_SouthAmerica(row):
    if row['Region'] == 'South America':
        return '1'
    return '0'

def label_NorthernEurope(row):
    if row['Region'] == 'Northern Europe':
        return '1'
    return '0'

# %%
df2.apply (lambda row: label_EastAsia(row), axis=1)
#axis1 == do at a row
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 212    0
# 213    0
# 214    0
# 215    0
# 216    0
# Length: 217, dtype: object

# %%
df2['EastAsia'] = df2.apply (lambda row: label_EastAsia(row), axis=1)
df2['SouthAmerica'] = df2.apply (lambda row: label_SouthAmerica(row), axis=1)
df2['NorthernEurope'] = df2.apply (lambda row: label_NorthernEurope(row), axis=1)
df2
# Out:
#                CountryName                 Region  ThirdWorld EastAsia  \
# 0              Afghanistan             South Asia           1        0
# 1                  Albania         Eastern Europe           0        0
# 2                  Algeria                 Africa           0        0
# 3           American Samoa  Australia and Oceanea           0        0
# 4                  Andorra         Western Europe           0        0
# ..                     ...                    ...         ...      ...
# 212  Virgin Islands (U.S.)          North America           0        0
# 213     West Bank and Gaza            Middle East           0        0
# 214            Yemen, Rep.            Middle East           1        0
# 215                 Zambia                 Africa           1        0
# 216               Zimbabwe                 Africa           0        0
#
#     SouthAmerica NorthernEurope
# 0              0              0
# 1              0              0
# ...

# %%
df2[df2.EastAsia =='1']
# Out:
#                    CountryName     Region  ThirdWorld EastAsia SouthAmerica  \
# 41                       China  East Asia           0        1            0
# 86        Hong Kong SAR, China  East Asia           0        1            0
# 98                       Japan  East Asia           0        1            0
# 103  Korea, Dem. People’s Rep.  East Asia           0        1            0
# 104                Korea, Rep.  East Asia           0        1            0
# 117           Macao SAR, China  East Asia           0        1            0
# 131                   Mongolia  East Asia           0        1            0
#
#     NorthernEurope
# 41               0
# 86               0
# 98               0
# 103              0
# 104              0
# 117              0
# 131              0

# %%
df2[df2.SouthAmerica =='1']
# Out:
#        CountryName         Region  ThirdWorld EastAsia SouthAmerica  \
# 7        Argentina  South America           0        0            1
# 23         Bolivia  South America           0        0            1
# 26          Brazil  South America           0        0            1
# 40           Chile  South America           0        0            1
# 42        Colombia  South America           0        0            1
# 57         Ecuador  South America           0        0            1
# 83          Guyana  South America           0        0            1
# 153       Paraguay  South America           0        0            1
# 154           Peru  South America           0        0            1
# 186       Suriname  South America           0        0            1
# 207        Uruguay  South America           0        0            1
# 210  Venezuela, RB  South America           0        0            1
#
#     NorthernEurope
# 7                0
# 23               0
# 26               0
# ...

# %%
df2
# Out:
#                CountryName                 Region  ThirdWorld EastAsia  \
# 0              Afghanistan             South Asia           1        0
# 1                  Albania         Eastern Europe           0        0
# 2                  Algeria                 Africa           0        0
# 3           American Samoa  Australia and Oceanea           0        0
# 4                  Andorra         Western Europe           0        0
# ..                     ...                    ...         ...      ...
# 212  Virgin Islands (U.S.)          North America           0        0
# 213     West Bank and Gaza            Middle East           0        0
# 214            Yemen, Rep.            Middle East           1        0
# 215                 Zambia                 Africa           1        0
# 216               Zimbabwe                 Africa           0        0
#
#     SouthAmerica NorthernEurope
# 0              0              0
# 1              0              0
# ...

# %%
df2.to_csv('country_with_myRegion.csv',index=False)
