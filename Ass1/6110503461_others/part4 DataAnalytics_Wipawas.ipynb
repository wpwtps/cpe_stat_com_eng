# %%
import os
os.chdir('C:\\Users\\User\\Documents\\stat2020\\Week2_data\\transportation')
os.getcwd()
# Out:
# 'C:\\Users\\User\\Documents\\stat2020\\Week2_data\\transportation'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('airTrans_gdp_etertia_2012_2016.csv',sep=',', header='infer')
df.head()
# Out:
#       CountryName                 Region  ThirdWorld  airTrans2012  \
# 0     Afghanistan             South Asia           1  17775.000000
# 1         Albania         Eastern Europe           0  10309.179138
# 2         Algeria                 Africa           0  54292.000000
# 3  American Samoa  Australia and Oceanea           0   3963.003648
# 4         Andorra         Western Europe           0           NaN
#
#    airTrans2016       gdp2012       gdp2016  enrollTertiary2012  \
# 0       22770.0    641.872034    547.228110                 NaN
# 1         306.0   4247.614342   4124.108543            59.25201
# 2       73465.0   5592.221910   3948.811897            32.20153
# 3           NaN  11568.793001  11714.895678                 NaN
# 4           NaN  38392.943901  37224.108916                 NaN
#
#    enrollTertiary2016
# 0                 NaN
# 1            58.38185
# 2            42.62885
# 3                 NaN
# 4                 NaN

# %%
df2 = df.drop(['ThirdWorld'], axis=1)

# %%
df2
# Out:
#                CountryName                 Region  airTrans2012  airTrans2016  \
# 0              Afghanistan             South Asia  17775.000000       22770.0
# 1                  Albania         Eastern Europe  10309.179138         306.0
# 2                  Algeria                 Africa  54292.000000       73465.0
# 3           American Samoa  Australia and Oceanea   3963.003648           NaN
# 4                  Andorra         Western Europe           NaN           NaN
# ..                     ...                    ...           ...           ...
# 212  Virgin Islands (U.S.)          North America           NaN           NaN
# 213     West Bank and Gaza            Middle East           NaN           NaN
# 214            Yemen, Rep.            Middle East  16807.407296        4538.0
# 215                 Zambia                 Africa   8288.000000        8094.0
# 216               Zimbabwe                 Africa  11560.367854        4231.0
#
# ...

# %%
df3 = df2.airTrans2012

# %%
df4 = df2.gdp2012

# %%
df3.corr(df4)
# Out:
# 0.1973152880532039

# %%
import matplotlib.pyplot as plt
df2.plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Region', fontsize=20);

# %%
air = pd.read_excel('airtransport.xlsx',sheet_name='Data')
air
# Out:
#                                            Series Name  Series Code  \
# 0    Air transport, registered carrier departures w...  IS.AIR.DPRT
# 1    Air transport, registered carrier departures w...  IS.AIR.DPRT
# 2    Air transport, registered carrier departures w...  IS.AIR.DPRT
# 3    Air transport, registered carrier departures w...  IS.AIR.DPRT
# 4    Air transport, registered carrier departures w...  IS.AIR.DPRT
# ..                                                 ...          ...
# 217                                                NaN          NaN
# 218                                                NaN          NaN
# 219                                                NaN          NaN
# 220   Data from database: World Development Indicators          NaN
# 221                           Last Updated: 10/28/2019          NaN
#
#        Country Name Country Code 1990 [YR1990] 2000 [YR2000] 2010 [YR2010]  \
# ...

# %%
air.drop([217, 218, 219, 220, 221], inplace=True)
air
# Out:
#                                            Series Name  Series Code  \
# 0    Air transport, registered carrier departures w...  IS.AIR.DPRT
# 1    Air transport, registered carrier departures w...  IS.AIR.DPRT
# 2    Air transport, registered carrier departures w...  IS.AIR.DPRT
# 3    Air transport, registered carrier departures w...  IS.AIR.DPRT
# 4    Air transport, registered carrier departures w...  IS.AIR.DPRT
# ..                                                 ...          ...
# 212  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 213  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 214  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 215  Air transport, registered carrier departures w...  IS.AIR.DPRT
# 216  Air transport, registered carrier departures w...  IS.AIR.DPRT
#
#               Country Name Country Code 1990 [YR1990] 2000 [YR2000]  \
# 0              Afghanistan          AFG          5300          3409
# ...

# %%
air2 = air.drop(['Series Name','Series Code','Country Code','Country Code'], axis=1)
air2
# Out:
#               Country Name 1990 [YR1990] 2000 [YR2000] 2010 [YR2010]  \
# 0              Afghanistan          5300          3409         21677
# 1                  Albania            ..          3885          9412
# 2                  Algeria         44100         40202         53088
# 3           American Samoa            ..            ..       3420.57
# 4                  Andorra            ..            ..            ..
# ..                     ...           ...           ...           ...
# 212  Virgin Islands (U.S.)            ..            ..            ..
# 213     West Bank and Gaza            ..            ..            ..
# 214            Yemen, Rep.         14100         14608         20600
# 215                 Zambia          6500          6118          9730
# 216               Zimbabwe         10300         13603          7077
#
#     2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015]  \
# ...

# %%
air2.replace({'..':np.nan}, inplace=True)
air2.head()
# Out:
#      Country Name  1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  2011 [YR2011]  \
# 0     Afghanistan         5300.0         3409.0   21677.000000   25021.000000
# 1         Albania            NaN         3885.0    9412.000000   10373.210942
# 2         Algeria        44100.0        40202.0   53088.000000   53286.000000
# 3  American Samoa            NaN            NaN    3420.570755    3577.613861
# 4         Andorra            NaN            NaN            NaN            NaN
#
#    2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  \
# 0   17775.000000        21696.0        25920.0        23532.0        22770.0
# 1   10309.179138        11196.0         1992.0            NaN          306.0
# 2   54292.000000        55516.0        60066.0        65940.0        73465.0
# 3    3963.003648         8580.0         9144.0            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
# ...

# %%
sns.heatmap(air2.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
air2.drop(['2019 [YR2019]'],axis=1, inplace=True)
air2.head()
# Out:
#      Country Name  1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  2011 [YR2011]  \
# 0     Afghanistan         5300.0         3409.0   21677.000000   25021.000000
# 1         Albania            NaN         3885.0    9412.000000   10373.210942
# 2         Algeria        44100.0        40202.0   53088.000000   53286.000000
# 3  American Samoa            NaN            NaN    3420.570755    3577.613861
# 4         Andorra            NaN            NaN            NaN            NaN
#
#    2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  \
# 0   17775.000000        21696.0        25920.0        23532.0        22770.0
# 1   10309.179138        11196.0         1992.0            NaN          306.0
# 2   54292.000000        55516.0        60066.0        65940.0        73465.0
# 3    3963.003648         8580.0         9144.0            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    2017 [YR2017]  2018 [YR2018]
# ...

# %%
regions = pd.read_excel('countries_regions.xlsx')
regions.head()
# Out:
#       CountryName                 Region  ThirdWorld
# 0     Afghanistan             South Asia           1
# 1         Albania         Eastern Europe           0
# 2         Algeria                 Africa           0
# 3  American Samoa  Australia and Oceanea           0
# 4         Andorra         Western Europe           0

# %%
regions.drop(['ThirdWorld'],axis=1, inplace=True)
regions.head()
# Out:
#       CountryName                 Region
# 0     Afghanistan             South Asia
# 1         Albania         Eastern Europe
# 2         Algeria                 Africa
# 3  American Samoa  Australia and Oceanea
# 4         Andorra         Western Europe

# %%
air2.head()
# Out:
#      Country Name  1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  2011 [YR2011]  \
# 0     Afghanistan         5300.0         3409.0   21677.000000   25021.000000
# 1         Albania            NaN         3885.0    9412.000000   10373.210942
# 2         Algeria        44100.0        40202.0   53088.000000   53286.000000
# 3  American Samoa            NaN            NaN    3420.570755    3577.613861
# 4         Andorra            NaN            NaN            NaN            NaN
#
#    2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  \
# 0   17775.000000        21696.0        25920.0        23532.0        22770.0
# 1   10309.179138        11196.0         1992.0            NaN          306.0
# 2   54292.000000        55516.0        60066.0        65940.0        73465.0
# 3    3963.003648         8580.0         9144.0            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    2017 [YR2017]  2018 [YR2018]
# ...

# %%
air2
# Out:
#               Country Name  1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  \
# 0              Afghanistan         5300.0         3409.0   21677.000000
# 1                  Albania            NaN         3885.0    9412.000000
# 2                  Algeria        44100.0        40202.0   53088.000000
# 3           American Samoa            NaN            NaN    3420.570755
# 4                  Andorra            NaN            NaN            NaN
# ..                     ...            ...            ...            ...
# 212  Virgin Islands (U.S.)            NaN            NaN            NaN
# 213     West Bank and Gaza            NaN            NaN            NaN
# 214            Yemen, Rep.        14100.0        14608.0   20600.000000
# 215                 Zambia         6500.0         6118.0    9730.000000
# 216               Zimbabwe        10300.0        13603.0    7077.000000
#
#      2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  \
# ...

# %%
regair = regions.set_index('CountryName').join(air2.set_index('Country Name'))

regair
# Out:
#                                       Region  1990 [YR1990]  2000 [YR2000]  \
# CountryName
# Afghanistan                       South Asia         5300.0         3409.0
# Albania                       Eastern Europe            NaN         3885.0
# Algeria                               Africa        44100.0        40202.0
# American Samoa         Australia and Oceanea            NaN            NaN
# Andorra                       Western Europe            NaN            NaN
# ...                                      ...            ...            ...
# Virgin Islands (U.S.)          North America            NaN            NaN
# West Bank and Gaza               Middle East            NaN            NaN
# Yemen, Rep.                      Middle East        14100.0        14608.0
# Zambia                                Africa         6500.0         6118.0
# Zimbabwe                              Africa        10300.0        13603.0
#
# ...

# %%
air2.to_csv('air2.csv',index=False)

# %%
cair2 = regair.dropna()
cair2
# Out:
#                              Region  1990 [YR1990]  2000 [YR2000]  \
# CountryName
# Afghanistan              South Asia         5300.0         3409.0
# Algeria                      Africa        44100.0        40202.0
# Angola                       Africa         6900.0         4399.0
# Antigua and Barbuda   North America        58000.0        62070.0
# Argentina             South America       114000.0       168815.0
# ...                             ...            ...            ...
# Venezuela, RB         South America        82000.0       138500.0
# Vietnam              Southeast Asia         1800.0        28999.0
# Yemen, Rep.             Middle East        14100.0        14608.0
# Zambia                       Africa         6500.0         6118.0
# Zimbabwe                     Africa        10300.0        13603.0
#
#                      2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  \
# CountryName
# Afghanistan            21677.00000   25021.000000   17775.000000
# ...

# %%
cair2
# Out:
#                              Region  1990 [YR1990]  2000 [YR2000]  \
# CountryName
# Afghanistan              South Asia         5300.0         3409.0
# Algeria                      Africa        44100.0        40202.0
# Angola                       Africa         6900.0         4399.0
# Antigua and Barbuda   North America        58000.0        62070.0
# Argentina             South America       114000.0       168815.0
# ...                             ...            ...            ...
# Venezuela, RB         South America        82000.0       138500.0
# Vietnam              Southeast Asia         1800.0        28999.0
# Yemen, Rep.             Middle East        14100.0        14608.0
# Zambia                       Africa         6500.0         6118.0
# Zimbabwe                     Africa        10300.0        13603.0
#
#                      2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  \
# CountryName
# Afghanistan            21677.00000   25021.000000   17775.000000
# ...

# %%
cair2.set_index('Region')
# Out:
#                 1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  2011 [YR2011]  \
# Region
# South Asia             5300.0         3409.0    21677.00000   25021.000000
# Africa                44100.0        40202.0    53088.00000   53286.000000
# Africa                 6900.0         4399.0    17060.00000   12282.000000
# North America         58000.0        62070.0    39865.00000   36533.603997
# South America        114000.0       168815.0    92847.50654   90214.520534
# ...                       ...            ...            ...            ...
# South America         82000.0       138500.0    84065.00000   83106.000000
# Southeast Asia         1800.0        28999.0   109176.00000  135905.672937
# Middle East           14100.0        14608.0    20600.00000   20176.728526
# Africa                 6500.0         6118.0     9730.00000   11497.000000
# Africa                10300.0        13603.0     7077.00000   10020.705611
#
# ...

# %%
cair2.groupby(by="Region").mean()
# Out:
#                        1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  \
# Region
# Africa                  13383.333333   16272.633333   2.852942e+04
# Australia and Oceanea   80250.000000  120121.833333   1.440410e+05
# East Asia              199475.000000  361562.500000   8.983571e+05
# Eastern Europe          37260.000000   45741.600000   8.063105e+04
# Middle East             23321.428571   40861.142857   9.494915e+04
# North America          685490.909091  937244.272727   1.093437e+06
# Northern Europe        215475.000000  294844.500000   4.351119e+05
# South America           84270.000000  130180.800000   1.544286e+05
# South Asia              34928.571429   41511.142857   1.141529e+05
# Southeast Asia          57487.500000   62794.625000   1.641907e+05
# Thailand                69500.000000  101591.000000   2.013060e+05
# Western Europe         133407.692308  270761.923077   2.798705e+05
#
#                        2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# Region
# ...

# %%
cair2.to_csv('cair2.csv',index=False)

# %%
sns.heatmap(air2.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
regions = pd.read_excel('countries_regions.xlsx')

regions.head()
# Out:
#       CountryName                 Region  ThirdWorld
# 0     Afghanistan             South Asia           1
# 1         Albania         Eastern Europe           0
# 2         Algeria                 Africa           0
# 3  American Samoa  Australia and Oceanea           0
# 4         Andorra         Western Europe           0

# %%
reg1 = regions.drop(['ThirdWorld'],axis=1, inplace=True)
#air2.drop(['2019 [YR2019]'],axis=1, inplace=True)
reg1

# %%
air3 =air2.set_index('Country Name')

air4 = air3.dropna()
air4
# Out:
#                      1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  \
# Country Name
# Afghanistan                 5300.0         3409.0    21677.00000
# Algeria                    44100.0        40202.0    53088.00000
# Angola                      6900.0         4399.0    17060.00000
# Antigua and Barbuda        58000.0        62070.0    39865.00000
# Argentina                 114000.0       168815.0    92847.50654
# ...                            ...            ...            ...
# Venezuela, RB              82000.0       138500.0    84065.00000
# Vietnam                     1800.0        28999.0   109176.00000
# Yemen, Rep.                14100.0        14608.0    20600.00000
# Zambia                      6500.0         6118.0     9730.00000
# Zimbabwe                   10300.0        13603.0     7077.00000
#
#                      2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# Country Name
# Afghanistan           25021.000000   17775.000000   21696.000000
# ...

# %%
air4 = air3.T.plot(figsize=(112,10), legend=False, color='blue', alpha=0.2)

# %%
air5 = air2
air5
# Out:
#               Country Name  1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  \
# 0              Afghanistan         5300.0         3409.0   21677.000000
# 1                  Albania            NaN         3885.0    9412.000000
# 2                  Algeria        44100.0        40202.0   53088.000000
# 3           American Samoa            NaN            NaN    3420.570755
# 4                  Andorra            NaN            NaN            NaN
# ..                     ...            ...            ...            ...
# 212  Virgin Islands (U.S.)            NaN            NaN            NaN
# 213     West Bank and Gaza            NaN            NaN            NaN
# 214            Yemen, Rep.        14100.0        14608.0   20600.000000
# 215                 Zambia         6500.0         6118.0    9730.000000
# 216               Zimbabwe        10300.0        13603.0    7077.000000
#
#      2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  \
# ...

# %%
air5.index.name = 'Index_name'
air5
# Out:
#                      Country Name  1990 [YR1990]  2000 [YR2000]  \
# Index_name
# 0                     Afghanistan         5300.0         3409.0
# 1                         Albania            NaN         3885.0
# 2                         Algeria        44100.0        40202.0
# 3                  American Samoa            NaN            NaN
# 4                         Andorra            NaN            NaN
# ...                           ...            ...            ...
# 212         Virgin Islands (U.S.)            NaN            NaN
# 213            West Bank and Gaza            NaN            NaN
# 214                   Yemen, Rep.        14100.0        14608.0
# 215                        Zambia         6500.0         6118.0
# 216                      Zimbabwe        10300.0        13603.0
#
#             2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# Index_name
# 0            21677.000000   25021.000000   17775.000000        21696.0
# ...

# %%
air3.plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Index_name', fontsize=20);

# %%
air4
# Out:
# <AxesSubplot:>

# %%
air4.to_csv('air4.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-9330ab920050> in <module>
# ----> 1 air4.to_csv('air4.csv',index=False)
#
# AttributeError: 'AxesSubplot' object has no attribute 'to_csv'

# %%
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook
fname = cbook.get_sample_data('air4.csv', asfileobj=False)
plt.plotfile(fname, ('Afghanistan', 'Algeria', 'Angola', 'Argentina', 'Zambia'), subplots=False)

# %%
air4.plot.barh(x=None, y=None, **kwargs)[source]

# %%
speed = [0.1, 17.5, 40, 48, 52, 69, 88]
lifespan = [2, 8, 70, 1.5, 25, 12, 28]
index = ['snail', 'pig', 'elephant',
         'rabbit', 'giraffe', 'coyote', 'horse']
df = pd.DataFrame({'speed': speed,
                   'lifespan': lifespan}, index=index)

# %%
df

# %%
ax = df.plot.barh(x='lifespan',y='speed')
